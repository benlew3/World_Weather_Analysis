# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Out:
# iqaluit ca
# hilo us
# ushuaia ar
# albany au
# cape town za
# joshimath in
# marawi sd
# dandong cn
# rikitea pf
# rikitea pf
# washington us
# sisimiut gl
# barrow us
# busselton au
# barrow us
# wattegama lk
# severo-kurilsk ru
# fukue jp
# kavieng pg
# qaanaaq gl
# samusu ws
# viligili mv
# carnarvon au
# dukat ru
# ban dung th
# puerto ayora ec
# asau tv
# longyearbyen sj
# taolanaro mg
# chimbote pe
# paz de ariporo co
# ushuaia ar
# busselton au
# saleaula ws
# nizhneyansk ru
# iqaluit ca
# torbay ca
# mar del plata ar
# yumen cn
# ponta do sol cv
# atuona pf
# mataura pf
# busselton au
# cockburn harbour tc
# cayenne gf
# dikson ru
# kashiwazaki jp
# butaritari ki
# mataura pf
# vaini to
# ushuaia ar
# rikitea pf
# port hardy ca
# matara lk
# bengkulu id
# pevek ru
# lasa cn
# port alfred za
# samusu ws
# kapaa us
# mrakovo ru
# tigil ru
# tsihombe mg
# eenhana na
# berdigestyakh ru
# hualmay pe
# goldap pl
# chokurdakh ru
# souillac mu
# umm lajj sa
# tuktoyaktuk ca
# port elizabeth za
# taolanaro mg
# constitucion mx
# rikitea pf
# hambantota lk
# hambantota lk
# victoria sc
# dikson ru
# clyde river ca
# palmer us
# torbay ca
# rikitea pf
# albany au
# mar del plata ar
# airai pw
# boueni yt
# bluff nz
# rikitea pf
# kayerkan ru
# buluang ph
# shizukuishi jp
# port hardy ca
# punta arenas cl
# saleaula ws
# great falls us
# yellowknife ca
# vaitupu wf
# viedma ar
# sentyabrskiy ru
# yellowknife ca
# cape town za
# hilo us
# port-gentil ga
# qaanaaq gl
# batemans bay au
# knysna za
# anloga gh
# thompson ca
# jamestown sh
# mahebourg mu
# muros es
# new norfolk au
# rikitea pf
# tiksi ru
# albany au
# da lat vn
# oktyabrskiy ru
# pevek ru
# hilo us
# ribeira grande pt
# samusu ws
# saint-philippe re
# albany au
# atuona pf
# ancud cl
# bredasdorp za
# jamestown sh
# sao filipe cv
# atuona pf
# ushuaia ar
# saint george bm
# hermanus za
# jamestown sh
# rikitea pf
# georgetown sh
# baie du tombeau mu
# port alfred za
# adrar dz
# high level ca
# maues br
# kavieng pg
# beringovskiy ru
# nara ml
# ushuaia ar
# chivay pe
# tasiilaq gl
# cape town za
# jamestown sh
# hithadhoo mv
# tecoanapa mx
# new norfolk au
# ushuaia ar
# palora ec
# puerto ayora ec
# maceio br
# carnarvon au
# port alfred za
# sao joao da barra br
# ancud cl
# makakilo city us
# avarua ck
# alofi nu
# thompson ca
# thompson ca
# hokitika nz
# lavrentiya ru
# castro cl
# barentsburg sj
# tasiilaq gl
# punta arenas cl
# sheregesh ru
# avarua ck
# hermanus za
# zhezkazgan kz
# srinagar in
# cape town za
# pevek ru
# rikitea pf
# cherskiy ru
# new norfolk au
# cherskiy ru
# dikson ru
# humberto de campos br
# busselton au
# mataura pf
# soe id
# ushuaia ar
# cape town za
# quatre cocos mu
# tuktoyaktuk ca
# wasilla us
# gizo sb
# tasiilaq gl
# waw sd
# rikitea pf
# bengkulu id
# lima pe
# cape town za
# thompson ca
# geraldton au
# bengkulu id
# qaanaaq gl
# dordrecht za
# bluff nz
# nikolskoye ru
# punta arenas cl
# taolanaro mg
# zaragoza es
# albany au
# bulgan mn
# longyearbyen sj
# zeya ru
# daru pg
# saleaula ws
# ewa beach us
# grafenhainichen de
# ndele cf
# hilo us
# ilulissat gl
# mataura pf
# rikitea pf
# mataura pf
# mataura pf
# laramie us
# oranjestad aw
# mataura pf
# alofi nu
# atuona pf
# albany au
# payakumbuh id
# sofiysk ru
# rikitea pf
# denpasar id
# pevek ru
# soyo ao
# bengkulu id
# busselton au
# sao felix do xingu br
# avarua ck
# punta arenas cl
# punta arenas cl
# mataura pf
# alofi nu
# bambous virieux mu
# kotido ug
# mangai cd
# mount pleasant us
# lashio mm
# matsanga cg
# yellowknife ca
# charters towers au
# srednekolymsk ru
# rosetown ca
# san patricio mx
# tshela cd
# saint george bm
# los llanos de aridane es
# drayton valley ca
# tuktoyaktuk ca
# svetlyy ru
# rikitea pf
# nizhneyansk ru
# bonfim br
# faya td
# taolanaro mg
# bambanglipuro id
# port elizabeth za
# illoqqortoormiut gl
# qaanaaq gl
# samusu ws
# labuhan id
# santa fe cu
# isangel vu
# ushuaia ar
# juneau us
# barrow us
# ushuaia ar
# lebu cl
# khatanga ru
# lewistown us
# ushuaia ar
# busselton au
# hilo us
# yarmouth ca
# northam au
# tabory ru
# paso de carrasco uy
# lithakia gr
# punta arenas cl
# ushuaia ar
# taolanaro mg
# nizhneyansk ru
# illoqqortoormiut gl
# attawapiskat ca
# villa rica co
# bethel us
# kamakwie sl
# kawalu id
# mar del plata ar
# punta arenas cl
# belushya guba ru
# ginir et
# tocache pe
# arraial do cabo br
# poum nc
# hobart au
# kuusamo fi
# rikitea pf
# bethel us
# bur gabo so
# thompson ca
# mahebourg mu
# iqaluit ca
# adrar dz
# pevek ru
# sao raimundo das mangabeiras br
# hilo us
# serebryanyy bor ru
# rikitea pf
# cape town za
# east london za
# mar del plata ar
# laguna br
# kaihua cn
# mataura pf
# puerto ayora ec
# saint george bm
# kahului us
# dalaba gn
# harper lr
# bluff nz
# albany au
# hobart au
# port arthur us
# pevek ru
# vaini to
# ancud cl
# kodiak us
# havre-saint-pierre ca
# mataura pf
# marcona pe
# laguna br
# ushuaia ar
# ushuaia ar
# utiroa ki
# rikitea pf
# ushuaia ar
# barentsburg sj
# cape town za
# olinda br
# santa ana co
# bethel us
# sachin in
# avarua ck
# lebu cl
# grand river south east mu
# hermanus za
# lompoc us
# atuona pf
# yarkovo ru
# punta arenas cl
# katsuura jp
# zavitinsk ru
# yellowknife ca
# qaanaaq gl
# mataura pf
# port hedland au
# bluff nz
# ushuaia ar
# mataura pf
# nemuro jp
# qaanaaq gl
# cockburn town bs
# ostrovnoy ru
# saint-philippe re
# saint-pierre pm
# hobart au
# evensk ru
# tasiilaq gl
# nanortalik gl
# geraldton ca
# ewo cg
# pangnirtung ca
# mataura pf
# pingshan cn
# tasiilaq gl
# hermanus za
# conner ph
# hobart au
# punta arenas cl
# san juan us
# bilibino ru
# vila franca do campo pt
# tilichiki ru
# vaini to
# nome us
# nemuro jp
# cherskiy ru
# san francisco ar
# albany au
# buraydah sa
# chuy uy
# ponta do sol cv
# te anau nz
# illoqqortoormiut gl
# alekseyevsk ru
# ancud cl
# faanui pf
# palmer us
# esperance au
# kruisfontein za
# jamestown sh
# cape town za
# rikitea pf
# jamestown sh
# marcona pe
# mar del plata ar
# kaitangata nz
# ushuaia ar
# rikitea pf
# yellowknife ca
# marcona pe
# nago jp
# pindi gheb pk
# east london za
# talnakh ru
# mahebourg mu
# sao felix do xingu br
# ruatoria nz
# rikitea pf
# sept-iles ca
# cape town za
# hervey bay au
# albany au
# nikolskoye ru
# salalah om
# ushuaia ar
# gerash ir
# saint-joseph re
# ribeira grande pt
# okhotsk ru
# mrirt ma
# copiapo cl
# puerto ayora ec
# west wendover us
# kahului us
# isangel vu
# puerto ayora ec
# jamestown sh
# mataura pf
# kapaa us
# pevek ru
# rikitea pf
# nuevitas cu
# leshukonskoye ru
# somanda tz
# yellowknife ca
# grindavik is
# jamestown sh
# san carlos de bariloche ar
# kodiak us
# hermanus za
# luis correia br
# atuona pf
# hermanus za
# wulanhaote cn
# tuatapere nz
# bluff nz
# korla cn
# khajuraho in
# ushuaia ar
# cabo san lucas mx
# new norfolk au
# leningradskiy ru
# hobart au
# cabo san lucas mx
# tasiilaq gl
# atuona pf
# longyearbyen sj
# cape town za
# kruisfontein za
# constitucion mx
# mahebourg mu
# wadi musa jo
# esperance au
# port elizabeth za
# takoradi gh
# busselton au
# eyrarbakki is
# georgetown sh
# nome us
# hermanus za
# shetpe kz
# nishihara jp
# vaini to
# barentsburg sj
# guerrero negro mx
# hasaki jp
# arraial do cabo br
# neiafu to
# kapaa us
# namibe ao
# rikitea pf
# kapaa us
# cape town za
# lompoc us
# codrington ag
# ushuaia ar
# mehamn no
# pontianak id
# ilulissat gl
# georgetown sh
# the pas ca
# bilma ne
# dire ml
# puerto ayora ec
# dordrecht za
# ayorou ne
# lompoc us
# port alfred za
# vaini to
# bluff nz
# punta arenas cl
# tuktoyaktuk ca
# hermanus za
# saint-augustin ca
# saint george bm
# lovozero ru
# barrow us
# guerrero negro mx
# punta arenas cl
# rikitea pf
# muli mv
# mataura pf
# lebu cl
# havre-saint-pierre ca
# butaritari ki
# kavieng pg
# punta arenas cl
# tawkar sd
# santa vitoria do palmar br
# tigil ru
# hilo us
# paita pe
# east london za
# kapaa us
# port hueneme us
# poli cm
# samusu ws
# bluff nz
# cimarron hills us
# mahebourg mu
# alice springs au
# illoqqortoormiut gl
# katobu id
# longyearbyen sj
# rikitea pf
# chuy uy
# sinnamary gf
# petropavlovsk-kamchatskiy ru
# barentsburg sj
# guerrero negro mx
# carnarvon au
# iqaluit ca
# belmonte br
# jamestown sh
# hilo us
# hamilton bm
# karak pk
# fortuna us
# antiguo morelos mx
# cape town za
# mahebourg mu
# busselton au
# albany au
# praia cv
# hilo us
# faanui pf
# chokurdakh ru
# busselton au
# novska hr
# portland au
# kalmunai lk
# vaitupu wf
# kieta pg
# halalo wf
# bonavista ca
# atuona pf
# lagoa pt
# mahebourg mu
# cape town za
# mar del plata ar
# yellowknife ca
# labuhan id
# arraial do cabo br
# san ramon bo
# pacific grove us
# kodiak us
# anshun cn
# yar-sale ru
# punta arenas cl
# mataura pf
# punta arenas cl
# cape town za
# nioki cd
# singapore sg
# vaini to
# coahuayana mx
# upernavik gl
# busselton au
# ushuaia ar
# boca do acre br
# meulaboh id
# aksu cn
# tuktoyaktuk ca
# maniitsoq gl
# diamantino br
# nome us
# peniche pt
# vaini to
# raudeberg no
# rikitea pf
# hermanus za
# pontianak id
# bandarbeyla so
# bluff nz
# kapaa us
# faanui pf
# katangli ru
# albany au
# nuuk gl
# cidreira br
# belushya guba ru
# aranos na
# bluff nz
# hammerfest no
# mandalgovi mn
# provideniya ru
# baiyin cn
# mount vernon us
# puerto padre cu
# levelland us
# ushuaia ar
# yellowknife ca
# albany au
# hilo us
# bluff nz
# airai pw
# saint-augustin ca
# vaini to
# punta arenas cl
# mana gf
# atuona pf
# butaritari ki
# saleaula ws
# hobart au
# punta arenas cl
# talnakh ru
# atar mr
# qaanaaq gl
# barrow us
# attawapiskat ca
# rikitea pf
# provideniya ru
# aklavik ca
# bambous virieux mu
# khuzhir ru
# rikitea pf
# busselton au
# ailigandi pa
# iqaluit ca
# kaitangata nz
# hithadhoo mv
# atuona pf
# sergeyevka kz
# broken hill au
# albany au
# rikitea pf
# tuktoyaktuk ca
# atuona pf
# narsaq gl
# ushuaia ar
# boddam gb
# salinopolis br
# westport ie
# bluff nz
# sorsk ru
# narasimharajapura in
# rikitea pf
# vila vu
# ilulissat gl
# mahebourg mu
# marathon ca
# khatanga ru
# busselton au
# hobart au
# samusu ws
# cape town za
# yellowknife ca
# castro cl
# ushuaia ar
# labrea br
# amderma ru
# hithadhoo mv
# saint-paul re
# mackay au
# ilulissat gl
# ahipara nz
# fort nelson ca
# husavik is
# fortuna us
# juli pe
# rawson ar
# puerto madryn ar
# tuktoyaktuk ca
# lardos gr
# mys shmidta ru
# sao joao da barra br
# punta arenas cl
# chokurdakh ru
# butaritari ki
# avarua ck
# rikitea pf
# kota bahru my
# saint-augustin ca
# borovoy ru
# bonoua ci
# atuona pf
# new norfolk au
# rikitea pf
# bambous virieux mu
# albany au
# nikolskoye ru
# crab hill bb
# punta arenas cl
# sentyabrskiy ru
# requena pe
# bredasdorp za
# yerbogachen ru
# ciechocinek pl
# albany au
# road town vg
# saint-philippe re
# yellowknife ca
# hobart au
# souillac mu
# along in
# cerritos mx
# nouadhibou mr
# kavaratti in
# lebu cl
# nikolskoye ru
# punta arenas cl
# albany au
# butaritari ki
# muros es
# sentyabrskiy ru
# tasiilaq gl
# georgetown sh
# rikitea pf
# ushuaia ar
# kruisfontein za
# klaksvik fo
# pemangkat id
# kimbe pg
# severomuysk ru
# burns lake ca
# saint-philippe re
# rikitea pf
# ushuaia ar
# cape town za
# rikitea pf
# vaini to
# sosnovo-ozerskoye ru
# lompoc us
# yellowknife ca
# luba gq
# santa helena br
# paciran id
# jamestown sh
# airai pw
# east london za
# punta arenas cl
# kapaa us
# nogent-le-rotrou fr
# busselton au
# carnarvon au
# belushya guba ru
# ushuaia ar
# san policarpo ph
# visby se
# ambanja mg
# rikitea pf
# isangel vu
# port lincoln au
# hasaki jp
# itoman jp
# kruisfontein za
# tura ru
# faanui pf
# illoqqortoormiut gl
# taolanaro mg
# pisco pe
# cape town za
# tsihombe mg
# port lincoln au
# taolanaro mg
# yellowknife ca
# bluff nz
# hobart au
# kyshtovka ru
# sheregesh ru
# kupang id
# corinto ni
# cabo san lucas mx
# busselton au
# vaini to
# aklavik ca
# jamestown sh
# albany au
# albany au
# tilichiki ru
# mahebourg mu
# albany au
# taolanaro mg
# nizhneyansk ru
# mogadishu so
# thompson ca
# adrar dz
# waldorf us
# kodiak us
# vila velha br
# tasiilaq gl
# camopi gf
# buritizeiro br
# saint anthony ca
# ushuaia ar
# vaini to
# umea se
# hofn is
# tindwari in
# tecoanapa mx
# albany au
# dingle ie
# busselton au
# poum nc
# yeppoon au
# flin flon ca
# ylivieska fi
# punta arenas cl
# albany au
# castro cl
# ushuaia ar
# new norfolk au
# cape town za
# usinsk ru
# grand river south east mu
# sinnamary gf
# albany au
# sumkino ru
# mar del plata ar
# broken hill au
# hambantota lk
# rikitea pf
# chokurdakh ru
# riyadh sa
# iranshahr ir
# chopinzinho br
# mgachi ru
# ushuaia ar
# vaini to
# carnarvon au
# pevek ru
# longyearbyen sj
# beringovskiy ru
# attawapiskat ca
# roald no
# illoqqortoormiut gl
# albany au
# belushya guba ru
# busselton au
# dikson ru
# neuquen ar
# hithadhoo mv
# souillac mu
# rikitea pf
# torbay ca
# taolanaro mg
# mount isa au
# sabang id
# henties bay na
# badaojiang cn
# mount isa au
# nikolskoye ru
# anar darreh af
# puerto ayora ec
# mataura pf
# ballina au
# mataura pf
# jawhar so
# mataura pf
# sioux lookout ca
# hofn is
# puerto ayora ec
# tasiilaq gl
# atambua id
# chokurdakh ru
# ambilobe mg
# rikitea pf
# tuktoyaktuk ca
# mount isa au
# busselton au
# montlucon fr
# albany au
# busselton au
# rikitea pf
# heilbron za
# busselton au
# caravelas br
# tuktoyaktuk ca
# butaritari ki
# ler sd
# fez ma
# bluff nz
# saint-francois gp
# cordeiro br
# torbay ca
# qaanaaq gl
# manggar id
# zavetnoye ru
# carnarvon au
# port-gentil ga
# busselton au
# seoul kr
# dikson ru
# vadso no
# terra santa br
# half moon bay us
# rikitea pf
# ilebo cd
# hermanus za
# soubre ci
# taolanaro mg
# hobart au
# cururupu br
# hermanus za
# jamestown sh
# punta arenas cl
# port lincoln au
# punta arenas cl
# avarua ck
# skelleftea se
# saleaula ws
# punta arenas cl
# tiksi ru
# shestakovo ru
# ponta do sol cv
# saleaula ws
# rikitea pf
# albany au
# redlands us
# mataura pf
# rungata ki
# castro cl
# chicaman gt
# tuatapere nz
# santa fe pa
# bandarbeyla so
# acajutla sv
# tuktoyaktuk ca
# punta arenas cl
# esperance au
# sena madureira br
# provideniya ru
# barrow us
# narsaq gl
# new norfolk au
# padang id
# fortuna us
# lebu cl
# longyearbyen sj
# punta arenas cl
# vanimo pg
# chokurdakh ru
# cobija bo
# narsaq gl
# geraldton ca
# san quintin mx
# tilichiki ru
# berlevag no
# ushuaia ar
# hermanus za
# punta arenas cl
# poum nc
# carnarvon au
# khatanga ru
# saskylakh ru
# santa rosa bo
# punta arenas cl
# port alfred za
# priego de cordoba es
# san patricio mx
# bethel us
# hilo us
# mataura pf
# susangerd ir
# ulaangom mn
# cajabamba pe
# shelburne ca
# amderma ru
# cherskiy ru
# luanda ao
# trelew ar
# newport us
# cape town za
# hobart au
# ust-ishim ru
# arraial do cabo br
# qaanaaq gl
# hovd mn
# busselton au
# nome us
# taolanaro mg
# baykit ru
# naze jp
# kodiak us
# mys shmidta ru
# mataura pf
# ushuaia ar
# ushuaia ar
# puerto madryn ar
# hilo us
# busselton au
# isangel vu
# jamestown sh
# rikitea pf
# cabo san lucas mx
# kapaa us
# am timan td
# tual id
# illoqqortoormiut gl
# samarai pg
# faanui pf
# kahului us
# tsihombe mg
# new norfolk au
# mahebourg mu
# castro cl
# faanui pf
# new norfolk au
# alvaraes br
# port elizabeth za
# busselton au
# codrington ag
# calatayud es
# los llanos de aridane es
# hobart au
# qaanaaq gl
# provideniya ru
# vila franca do campo pt
# saint-denis re
# busselton au
# bluff nz
# grand gaube mu
# ushuaia ar
# huai yot th
# lata sb
# tsihombe mg
# gillette us
# san cristobal ec
# chuy uy
# ahipara nz
# hithadhoo mv
# albany au
# saint-pierre pm
# airai pw
# ngukurr au
# avarua ck
# saldanha za
# dymer ua
# padang id
# arraial do cabo br
# samusu ws
# sao joao da barra br
# edd er
# hithadhoo mv
# kapaa us
# mahebourg mu
# georgetown sh
# dekoa cf
# kargasok ru
# new norfolk au
# grand centre ca
# berlevag no
# batagay-alyta ru
# quatre cocos mu
# san quintin mx
# nizhneyansk ru
# gravdal no
# delta del tigre uy
# south lake tahoe us
# tuktoyaktuk ca
# kozelsk ru
# jamestown sh
# kirakira sb
# rikitea pf
# hasaki jp
# albany au
# kruisfontein za
# raudeberg no
# ngukurr au
# shelburne ca
# umtata za
# vaini to
# albany au
# amderma ru
# illoqqortoormiut gl
# dikson ru
# adrar dz
# amasia am
# butaritari ki
# rikitea pf
# belushya guba ru
# dingle ie
# ushuaia ar
# punta arenas cl
# antofagasta cl
# ushuaia ar
# saint-raymond ca
# provideniya ru
# hilo us
# saskylakh ru
# port alfred za
# kulhudhuffushi mv
# malakwal pk
# vaini to
# la crosse us
# lebu cl
# georgetown sh
# nikolskoye ru
# ushuaia ar
# samarai pg
# palabuhanratu id
# sakakah sa
# busselton au
# rikitea pf
# pedro carbo ec
# bethel us
# faxinal br
# nikolskoye ru
# petropavlovsk-kamchatskiy ru
# nuuk gl
# hambantota lk
# olinda br
# vaini to
# yellowknife ca
# tuktoyaktuk ca
# albany au
# saskylakh ru
# lavrentiya ru
# acarau br
# jamestown sh
# sitka us
# ushuaia ar
# jamestown sh
# georgetown sh
# albany au
# hobart au
# luderitz na
# tiksi ru
# punta arenas cl
# makat kz
# kapaa us
# jamestown sh
# provideniya ru
# adrar dz
# cherskiy ru
# ushuaia ar
# barrow us
# caravelas br
# flinders au
# tasiilaq gl
# evensk ru
# kyzyl-suu kg
# saldanha za
# tuktoyaktuk ca
# hithadhoo mv
# fayaoue nc
# rikitea pf
# albany au
# vaini to
# rurrenabaque bo
# bolungarvik is
# ahipara nz
# barabinsk ru
# cape town za
# vaitupu wf
# luderitz na
# klaksvik fo
# avarua ck
# lebu cl
# lebu cl
# aquiraz br
# pevek ru
# mataura pf
# rikitea pf
# rikitea pf
# ayabaca pe
# ushuaia ar
# rikitea pf
# mataura pf
# busselton au
# nuuk gl
# busselton au
# lompoc us
# yellowknife ca
# tiarei pf
# taolanaro mg
# ayni tj
# portland au
# ushuaia ar
# canmore ca
# vila velha br
# milton nz
# isagarh in
# ushuaia ar
# east london za
# cruden bay gb
# barrow us
# bethel us
# carnarvon au
# ushuaia ar
# saleaula ws
# nikolskoye ru
# achisay kz
# beloha mg
# taolanaro mg
# marienburg sr
# port-gentil ga
# husavik is
# hilo us
# mataura pf
# rikitea pf
# punta arenas cl
# margate za
# pacific grove us
# havelock us
# qasigiannguit gl
# kharhial in
# port-cartier ca
# vaini to
# cherskiy ru
# barrow us
# laguna br
# katsuura jp
# puerto ayora ec
# kattivakkam in
# praia cv
# vanavara ru
# butaritari ki
# kapaa us
# ponta do sol cv
# souillac mu
# taolanaro mg
# lavrentiya ru
# coquimbo cl
# punta arenas cl
# nelson bay au
# pangnirtung ca
# saskylakh ru
# hermanus za
# kahului us
# georgetown sh
# port arthur us
# new norfolk au
# klaksvik fo
# severo-kurilsk ru
# rikitea pf
# albany au
# rikitea pf
# mayo ca
# high rock bs
# abu dhabi ae
# busselton au
# mersing my
# busselton au
# nizwa om
# ballitoville za
# sitka us
# la ronge ca
# severodvinsk ru
# rikitea pf
# yellowknife ca
# yamada jp
# mar del plata ar
# rikitea pf
# albany au
# ponta do sol pt
# viedma ar
# gujranwala pk
# atuona pf
# saskylakh ru
# grao mogol br
# chuy uy
# bahjoi in
# kodiak us
# taolanaro mg
# albany au
# portland au
# shihezi cn
# cherskiy ru
# rikitea pf
# albany au
# halifax ca
# jamestown sh
# carutapera br
# butaritari ki
# maniwaki ca
# mataura pf
# virginia beach us
# saint-philippe re
# belushya guba ru
# hobart au
# busselton au
# comodoro rivadavia ar
# mataura pf
# grand river south east mu
# busselton au
# talnakh ru
# butaritari ki
# kruisfontein za
# lavrentiya ru
# gherghesti ro
# rikitea pf
# vaitupu wf
# kahta tr
# ilulissat gl
# atasu kz
# atasu kz
# nome us
# khatanga ru
# tavda ru
# oviedo us
# vestmannaeyjar is
# rikitea pf
# punta arenas cl
# albany au
# saskylakh ru
# lancaster us
# cocobeach ga
# svetlaya ru
# avera pf
# saleaula ws
# punta arenas cl
# mys shmidta ru
# geraldton au
# punta arenas cl
# bluff nz
# kingaroy au
# ribeira grande pt
# hirara jp
# norman wells ca
# jamestown sh
# hobart au
# pisco pe
# bandarbeyla so
# greeley us
# khuzdar pk
# mzimba mw
# chokurdakh ru
# el ejido es
# khatanga ru
# bluff nz
# vaitupu wf
# nongan cn
# rikitea pf
# bronnoysund no
# castro cl
# casimiro castillo mx
# watsa cd
# bredasdorp za
# udachnyy ru
# pirgos gr
# pisco pe
# lebu cl
# jamestown sh
# saldanha za
# iqaluit ca
# jacareacanga br
# cururupu br
# conceicao do araguaia br
# bredasdorp za
# vaitupu wf
# mendi pg
# havelock us
# golyshmanovo ru
# kapaa us
# arraial do cabo br
# tasiilaq gl
# alofi nu
# illoqqortoormiut gl
# mataura pf
# albany au
# mar del plata ar
# kavieng pg
# cape town za
# leningradskiy ru
# yatou cn
# pevek ru
# rikitea pf
# arrecife es
# busselton au
# fort dodge us
# louisbourg ca
# shingu jp
# vung tau vn
# bredasdorp za
# mataura pf
# punta arenas cl
# port elizabeth za
# jamestown sh
# fairview ca
# ushuaia ar
# cherskiy ru
# port alfred za
# talas kg
# mataura pf
# kahului us
# avarua ck
# radcliff us
# bluff nz
# beira mz
# ishigaki jp
# qaanaaq gl
# new norfolk au
# waddan ly
# anadyr ru
# amderma ru
# yellowknife ca
# rikitea pf
# avarua ck
# souillac mu
# balkhash kz
# puerto madero mx
# ingham au
# srednekolymsk ru
# kodiak us
# lakes entrance au
# albany au
# laguna br
# tasiilaq gl
# eldikan ru
# svetlogorsk ru
# jamestown sh
# saint george bm
# port blair in
# pevek ru
# ushuaia ar
# rikitea pf
# gurskoye ru
# margate za
# high rock bs
# amapa br
# sampit id
# albany au
# rikitea pf
# rikitea pf
# heidelberg za
# harper lr
# tasiilaq gl
# terney ru
# port blair in
# ponta do sol cv
# hilo us
# kabalo cd
# mataura pf
# grand river south east mu
# rikitea pf
# rocha uy
# dikson ru
# busselton au
# sungurlu tr
# taolanaro mg
# saint-philippe re
# punta arenas cl
# tamworth au
# amderma ru
# lakatoro vu
# saint-philippe re
# salym ru
# merauke id
# bargal so
# cape town za
# gravdal no
# hualmay pe
# tiksi ru
# saskylakh ru
# vestmanna fo
# livingston us

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 608

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c8cc1f77bc87360422ad5bbb278cce61

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c8cc1f77bc87360422ad5bbb278cce61&q=Boston

# %%
# Make a 'Get' request for the city weather.
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Get the text of the 'Get' request.
city_weather.text
# Out:
# '{"coord":{"lon":-71.0598,"lat":42.3584},"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}],"base":"stations","main":{"temp":24.78,"feels_like":6.96,"temp_min":23,"temp_max":26.01,"pressure":1015,"humidity":39},"visibility":10000,"wind":{"speed":20.71,"deg":300,"gust":28.77},"clouds":{"all":1},"dt":1611537611,"sys":{"type":1,"id":3486,"country":"US","sunrise":1611489894,"sunset":1611524856},"timezone":-18000,"id":4930956,"name":"Boston","cod":200}'

# %%
# Get the JSON text of the 'Get' request.
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01n'}],
#  'base': 'stations',
#  'main': {'temp': 24.78,
#   'feels_like': 6.96,
#   'temp_min': 23,
#   'temp_max': 26.01,
#   'pressure': 1015,
#   'humidity': 39},
#  'visibility': 10000,
#  'wind': {'speed': 20.71, 'deg': 300, 'gust': 28.77},
#  'clouds': {'all': 1},
#  'dt': 1611537611,
#  'sys': {'type': 1,
#   'id': 3486,
#   'country': 'US',
#   'sunrise': 1611489894,
#   'sunset': 1611524856},
#  'timezone': -18000,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City Weather found.

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Bston"
city_weather = requests.get(city_url)
if city_weather.json():
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City Weather found.

# %%
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c8cc1f77bc87360422ad5bbb278cce61&q=Bston

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01n'}],
#  'base': 'stations',
#  'main': {'temp': 24.78,
#   'feels_like': 6.96,
#   'temp_min': 23,
#   'temp_max': 26.01,
#   'pressure': 1015,
#   'humidity': 39},
#  'visibility': 10000,
#  'wind': {'speed': 20.71, 'deg': 300, 'gust': 28.77},
#  'clouds': {'all': 1},
#  'dt': 1611537611,
#  'sys': {'type': 1,
#   'id': 3486,
#   'country': 'US',
#   'sunrise': 1611489894,
#   'sunset': 1611524856},
#  'timezone': -18000,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Get the JSON data.
boston_data = city_weather.json()

# %%
boston_data['sys']["country"]
# Out:
# 'US'

# %%
boston_data["dt"]
# Out:
# 1611537611

# %%
lat = boston_data["coord"]["lat"]
lng = boston_data["coord"]["lon"]
max_temp = boston_data["main"]["temp_max"]
humidity = boston_data["main"]["humidity"]
clouds = boston_data["clouds"]["all"]
wind = boston_data["wind"]["speed"]
print(lat, lng, max_temp, humidity, clouds, wind)
# Out:
# 42.3584 -71.0598 26.01 39 1 20.71

# %%
# Import the datetime module from the datetime library.
from datetime import datetime
# Get the date from the JSON file.
date = boston_data["dt"]
# Convert the UTC date to a date format with year, month, day, hours, minutes, and seconds.
datetime.utcfromtimestamp(date)
# Out:
# datetime.datetime(2021, 1, 25, 1, 20, 11)

# %%
datetime.utcfromtimestamp(date).strftime('%Y-%m-%d %H:%M:%S')
# Out:
# '2021-01-25 01:20:11'

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")

record_count += 1

print("Done")
# Out:
# Processing Record 1 of Set 13 | iqaluit
# Processing Record 2 of Set 13 | hilo
# Processing Record 3 of Set 13 | ushuaia
# Processing Record 4 of Set 13 | albany
# Processing Record 5 of Set 13 | cape town
# Processing Record 6 of Set 13 | joshimath
# Processing Record 7 of Set 13 | marawi
# Processing Record 8 of Set 13 | dandong
# Processing Record 9 of Set 13 | rikitea
# Processing Record 10 of Set 13 | washington
# Processing Record 11 of Set 13 | sisimiut
# Processing Record 12 of Set 13 | barrow
# Processing Record 13 of Set 13 | busselton
# Processing Record 14 of Set 13 | wattegama
# Processing Record 15 of Set 13 | severo-kurilsk
# Processing Record 16 of Set 13 | fukue
# Processing Record 17 of Set 13 | kavieng
# Processing Record 18 of Set 13 | qaanaaq
# Processing Record 19 of Set 13 | samusu
# City not found. Skipping...
# Processing Record 20 of Set 13 | viligili
# City not found. Skipping...
# Processing Record 21 of Set 13 | carnarvon
# Processing Record 22 of Set 13 | dukat
# Processing Record 23 of Set 13 | ban dung
# Processing Record 24 of Set 13 | puerto ayora
# Processing Record 25 of Set 13 | asau
# Processing Record 26 of Set 13 | longyearbyen
# Processing Record 27 of Set 13 | taolanaro
# City not found. Skipping...
# Processing Record 28 of Set 13 | chimbote
# Processing Record 29 of Set 13 | paz de ariporo
# City not found. Skipping...
# Processing Record 30 of Set 13 | saleaula
# City not found. Skipping...
# Processing Record 31 of Set 13 | nizhneyansk
# City not found. Skipping...
# Processing Record 32 of Set 13 | torbay
# Processing Record 33 of Set 13 | mar del plata
# Processing Record 34 of Set 13 | yumen
# Processing Record 35 of Set 13 | ponta do sol
# Processing Record 36 of Set 13 | atuona
# Processing Record 37 of Set 13 | mataura
# Processing Record 38 of Set 13 | cockburn harbour
# City not found. Skipping...
# Processing Record 39 of Set 13 | cayenne
# Processing Record 40 of Set 13 | dikson
# Processing Record 41 of Set 13 | kashiwazaki
# Processing Record 42 of Set 13 | butaritari
# Processing Record 43 of Set 13 | vaini
# Processing Record 44 of Set 13 | port hardy
# Processing Record 45 of Set 13 | matara
# Processing Record 46 of Set 13 | bengkulu
# Processing Record 47 of Set 13 | pevek
# Processing Record 48 of Set 13 | lasa
# Processing Record 49 of Set 13 | port alfred
# Processing Record 50 of Set 13 | kapaa
# Processing Record 1 of Set 14 | mrakovo
# Processing Record 2 of Set 14 | tigil
# Processing Record 3 of Set 14 | tsihombe
# City not found. Skipping...
# Processing Record 4 of Set 14 | eenhana
# Processing Record 5 of Set 14 | berdigestyakh
# Processing Record 6 of Set 14 | hualmay
# Processing Record 7 of Set 14 | goldap
# Processing Record 8 of Set 14 | chokurdakh
# Processing Record 9 of Set 14 | souillac
# Processing Record 10 of Set 14 | umm lajj
# Processing Record 11 of Set 14 | tuktoyaktuk
# Processing Record 12 of Set 14 | port elizabeth
# Processing Record 13 of Set 14 | constitucion
# Processing Record 14 of Set 14 | hambantota
# Processing Record 15 of Set 14 | victoria
# Processing Record 16 of Set 14 | clyde river
# Processing Record 17 of Set 14 | palmer
# Processing Record 18 of Set 14 | airai
# Processing Record 19 of Set 14 | boueni
# Processing Record 20 of Set 14 | bluff
# Processing Record 21 of Set 14 | kayerkan
# Processing Record 22 of Set 14 | buluang
# Processing Record 23 of Set 14 | shizukuishi
# Processing Record 24 of Set 14 | punta arenas
# Processing Record 25 of Set 14 | great falls
# Processing Record 26 of Set 14 | yellowknife
# Processing Record 27 of Set 14 | vaitupu
# City not found. Skipping...
# Processing Record 28 of Set 14 | viedma
# Processing Record 29 of Set 14 | sentyabrskiy
# City not found. Skipping...
# Processing Record 30 of Set 14 | port-gentil
# Processing Record 31 of Set 14 | batemans bay
# Processing Record 32 of Set 14 | knysna
# Processing Record 33 of Set 14 | anloga
# Processing Record 34 of Set 14 | thompson
# Processing Record 35 of Set 14 | jamestown
# Processing Record 36 of Set 14 | mahebourg
# Processing Record 37 of Set 14 | muros
# Processing Record 38 of Set 14 | new norfolk
# Processing Record 39 of Set 14 | tiksi
# Processing Record 40 of Set 14 | da lat
# Processing Record 41 of Set 14 | oktyabrskiy
# Processing Record 42 of Set 14 | ribeira grande
# Processing Record 43 of Set 14 | saint-philippe
# Processing Record 44 of Set 14 | ancud
# Processing Record 45 of Set 14 | bredasdorp
# Processing Record 46 of Set 14 | sao filipe
# Processing Record 47 of Set 14 | saint george
# Processing Record 48 of Set 14 | hermanus
# Processing Record 49 of Set 14 | georgetown
# Processing Record 50 of Set 14 | baie du tombeau
# City not found. Skipping...
# Processing Record 1 of Set 15 | adrar
# Processing Record 2 of Set 15 | high level
# Processing Record 3 of Set 15 | maues
# Processing Record 4 of Set 15 | beringovskiy
# Processing Record 5 of Set 15 | nara
# Processing Record 6 of Set 15 | chivay
# Processing Record 7 of Set 15 | tasiilaq
# Processing Record 8 of Set 15 | hithadhoo
# Processing Record 9 of Set 15 | tecoanapa
# Processing Record 10 of Set 15 | palora
# Processing Record 11 of Set 15 | maceio
# Processing Record 12 of Set 15 | sao joao da barra
# Processing Record 13 of Set 15 | makakilo city
# Processing Record 14 of Set 15 | avarua
# Processing Record 15 of Set 15 | alofi
# Processing Record 16 of Set 15 | hokitika
# Processing Record 17 of Set 15 | lavrentiya
# Processing Record 18 of Set 15 | castro
# Processing Record 19 of Set 15 | barentsburg
# City not found. Skipping...
# Processing Record 20 of Set 15 | sheregesh
# Processing Record 21 of Set 15 | zhezkazgan
# Processing Record 22 of Set 15 | srinagar
# Processing Record 23 of Set 15 | cherskiy
# Processing Record 24 of Set 15 | humberto de campos
# Processing Record 25 of Set 15 | soe
# Processing Record 26 of Set 15 | quatre cocos
# Processing Record 27 of Set 15 | wasilla
# Processing Record 28 of Set 15 | gizo
# Processing Record 29 of Set 15 | waw
# Processing Record 30 of Set 15 | lima
# Processing Record 31 of Set 15 | geraldton
# Processing Record 32 of Set 15 | dordrecht
# Processing Record 33 of Set 15 | nikolskoye
# Processing Record 34 of Set 15 | zaragoza
# Processing Record 35 of Set 15 | bulgan
# Processing Record 36 of Set 15 | zeya
# Processing Record 37 of Set 15 | daru
# Processing Record 38 of Set 15 | ewa beach
# Processing Record 39 of Set 15 | grafenhainichen
# Processing Record 40 of Set 15 | ndele
# Processing Record 41 of Set 15 | ilulissat
# Processing Record 42 of Set 15 | laramie
# Processing Record 43 of Set 15 | oranjestad
# Processing Record 44 of Set 15 | payakumbuh
# Processing Record 45 of Set 15 | sofiysk
# City not found. Skipping...
# Processing Record 46 of Set 15 | denpasar
# Processing Record 47 of Set 15 | soyo
# Processing Record 48 of Set 15 | sao felix do xingu
# Processing Record 49 of Set 15 | bambous virieux
# Processing Record 50 of Set 15 | kotido
# Processing Record 1 of Set 16 | mangai
# Processing Record 2 of Set 16 | mount pleasant
# Processing Record 3 of Set 16 | lashio
# Processing Record 4 of Set 16 | matsanga
# City not found. Skipping...
# Processing Record 5 of Set 16 | charters towers
# Processing Record 6 of Set 16 | srednekolymsk
# Processing Record 7 of Set 16 | rosetown
# Processing Record 8 of Set 16 | san patricio
# Processing Record 9 of Set 16 | tshela
# Processing Record 10 of Set 16 | los llanos de aridane
# Processing Record 11 of Set 16 | drayton valley
# Processing Record 12 of Set 16 | svetlyy
# Processing Record 13 of Set 16 | bonfim
# Processing Record 14 of Set 16 | faya
# Processing Record 15 of Set 16 | bambanglipuro
# Processing Record 16 of Set 16 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 17 of Set 16 | labuhan
# Processing Record 18 of Set 16 | santa fe
# Processing Record 19 of Set 16 | isangel
# Processing Record 20 of Set 16 | juneau
# Processing Record 21 of Set 16 | lebu
# Processing Record 22 of Set 16 | khatanga
# Processing Record 23 of Set 16 | lewistown
# Processing Record 24 of Set 16 | yarmouth
# Processing Record 25 of Set 16 | northam
# Processing Record 26 of Set 16 | tabory
# Processing Record 27 of Set 16 | paso de carrasco
# Processing Record 28 of Set 16 | lithakia
# Processing Record 29 of Set 16 | attawapiskat
# City not found. Skipping...
# Processing Record 30 of Set 16 | villa rica
# Processing Record 31 of Set 16 | bethel
# Processing Record 32 of Set 16 | kamakwie
# Processing Record 33 of Set 16 | kawalu
# Processing Record 34 of Set 16 | belushya guba
# City not found. Skipping...
# Processing Record 35 of Set 16 | ginir
# Processing Record 36 of Set 16 | tocache
# Processing Record 37 of Set 16 | arraial do cabo
# Processing Record 38 of Set 16 | poum
# Processing Record 39 of Set 16 | hobart
# Processing Record 40 of Set 16 | kuusamo
# Processing Record 41 of Set 16 | bur gabo
# City not found. Skipping...
# Processing Record 42 of Set 16 | sao raimundo das mangabeiras
# Processing Record 43 of Set 16 | serebryanyy bor
# Processing Record 44 of Set 16 | east london
# Processing Record 45 of Set 16 | laguna
# Processing Record 46 of Set 16 | kaihua
# Processing Record 47 of Set 16 | kahului
# Processing Record 48 of Set 16 | dalaba
# Processing Record 49 of Set 16 | harper
# Processing Record 50 of Set 16 | port arthur
# Processing Record 1 of Set 17 | kodiak
# Processing Record 2 of Set 17 | havre-saint-pierre
# Processing Record 3 of Set 17 | marcona
# City not found. Skipping...
# Processing Record 4 of Set 17 | utiroa
# City not found. Skipping...
# Processing Record 5 of Set 17 | olinda
# Processing Record 6 of Set 17 | santa ana
# Processing Record 7 of Set 17 | sachin
# Processing Record 8 of Set 17 | grand river south east
# City not found. Skipping...
# Processing Record 9 of Set 17 | lompoc
# Processing Record 10 of Set 17 | yarkovo
# Processing Record 11 of Set 17 | katsuura
# Processing Record 12 of Set 17 | zavitinsk
# Processing Record 13 of Set 17 | port hedland
# Processing Record 14 of Set 17 | nemuro
# Processing Record 15 of Set 17 | cockburn town
# Processing Record 16 of Set 17 | ostrovnoy
# Processing Record 17 of Set 17 | saint-pierre
# Processing Record 18 of Set 17 | evensk
# Processing Record 19 of Set 17 | nanortalik
# Processing Record 20 of Set 17 | ewo
# Processing Record 21 of Set 17 | pangnirtung
# Processing Record 22 of Set 17 | pingshan
# Processing Record 23 of Set 17 | conner
# Processing Record 24 of Set 17 | san juan
# Processing Record 25 of Set 17 | bilibino
# Processing Record 26 of Set 17 | vila franca do campo
# Processing Record 27 of Set 17 | tilichiki
# Processing Record 28 of Set 17 | nome
# Processing Record 29 of Set 17 | san francisco
# Processing Record 30 of Set 17 | buraydah
# Processing Record 31 of Set 17 | chuy
# Processing Record 32 of Set 17 | te anau
# Processing Record 33 of Set 17 | alekseyevsk
# Processing Record 34 of Set 17 | faanui
# Processing Record 35 of Set 17 | esperance
# Processing Record 36 of Set 17 | kruisfontein
# Processing Record 37 of Set 17 | kaitangata
# Processing Record 38 of Set 17 | nago
# Processing Record 39 of Set 17 | pindi gheb
# Processing Record 40 of Set 17 | talnakh
# Processing Record 41 of Set 17 | ruatoria
# City not found. Skipping...
# Processing Record 42 of Set 17 | sept-iles
# Processing Record 43 of Set 17 | hervey bay
# Processing Record 44 of Set 17 | salalah
# Processing Record 45 of Set 17 | gerash
# Processing Record 46 of Set 17 | saint-joseph
# Processing Record 47 of Set 17 | okhotsk
# Processing Record 48 of Set 17 | mrirt
# City not found. Skipping...
# Processing Record 49 of Set 17 | copiapo
# Processing Record 50 of Set 17 | west wendover
# Processing Record 1 of Set 18 | nuevitas
# Processing Record 2 of Set 18 | leshukonskoye
# Processing Record 3 of Set 18 | somanda
# Processing Record 4 of Set 18 | grindavik
# Processing Record 5 of Set 18 | san carlos de bariloche
# Processing Record 6 of Set 18 | luis correia
# Processing Record 7 of Set 18 | wulanhaote
# City not found. Skipping...
# Processing Record 8 of Set 18 | tuatapere
# Processing Record 9 of Set 18 | korla
# Processing Record 10 of Set 18 | khajuraho
# Processing Record 11 of Set 18 | cabo san lucas
# Processing Record 12 of Set 18 | leningradskiy
# Processing Record 13 of Set 18 | wadi musa
# Processing Record 14 of Set 18 | takoradi
# Processing Record 15 of Set 18 | eyrarbakki
# Processing Record 16 of Set 18 | shetpe
# Processing Record 17 of Set 18 | nishihara
# Processing Record 18 of Set 18 | guerrero negro
# Processing Record 19 of Set 18 | hasaki
# Processing Record 20 of Set 18 | neiafu
# Processing Record 21 of Set 18 | namibe
# Processing Record 22 of Set 18 | codrington
# Processing Record 23 of Set 18 | mehamn
# Processing Record 24 of Set 18 | pontianak
# Processing Record 25 of Set 18 | the pas
# Processing Record 26 of Set 18 | bilma
# Processing Record 27 of Set 18 | dire
# Processing Record 28 of Set 18 | ayorou
# Processing Record 29 of Set 18 | saint-augustin
# Processing Record 30 of Set 18 | lovozero
# Processing Record 31 of Set 18 | muli
# Processing Record 32 of Set 18 | tawkar
# City not found. Skipping...
# Processing Record 33 of Set 18 | santa vitoria do palmar
# Processing Record 34 of Set 18 | paita
# Processing Record 35 of Set 18 | port hueneme
# Processing Record 36 of Set 18 | poli
# Processing Record 37 of Set 18 | cimarron hills
# Processing Record 38 of Set 18 | alice springs
# Processing Record 39 of Set 18 | katobu
# Processing Record 40 of Set 18 | sinnamary
# Processing Record 41 of Set 18 | petropavlovsk-kamchatskiy
# Processing Record 42 of Set 18 | belmonte
# Processing Record 43 of Set 18 | hamilton
# Processing Record 44 of Set 18 | karak
# Processing Record 45 of Set 18 | fortuna
# Processing Record 46 of Set 18 | antiguo morelos
# Processing Record 47 of Set 18 | praia
# Processing Record 48 of Set 18 | novska
# Processing Record 49 of Set 18 | portland
# Processing Record 50 of Set 18 | kalmunai
# Processing Record 1 of Set 19 | kieta
# Processing Record 2 of Set 19 | halalo
# City not found. Skipping...
# Processing Record 3 of Set 19 | bonavista
# Processing Record 4 of Set 19 | lagoa
# Processing Record 5 of Set 19 | san ramon
# Processing Record 6 of Set 19 | pacific grove
# Processing Record 7 of Set 19 | anshun
# Processing Record 8 of Set 19 | yar-sale
# Processing Record 9 of Set 19 | nioki
# Processing Record 10 of Set 19 | singapore
# Processing Record 11 of Set 19 | coahuayana
# Processing Record 12 of Set 19 | upernavik
# Processing Record 13 of Set 19 | boca do acre
# Processing Record 14 of Set 19 | meulaboh
# Processing Record 15 of Set 19 | aksu
# Processing Record 16 of Set 19 | maniitsoq
# Processing Record 17 of Set 19 | diamantino
# Processing Record 18 of Set 19 | peniche
# Processing Record 19 of Set 19 | raudeberg
# Processing Record 20 of Set 19 | bandarbeyla
# Processing Record 21 of Set 19 | katangli
# Processing Record 22 of Set 19 | nuuk
# Processing Record 23 of Set 19 | cidreira
# Processing Record 24 of Set 19 | aranos
# Processing Record 25 of Set 19 | hammerfest
# Processing Record 26 of Set 19 | mandalgovi
# Processing Record 27 of Set 19 | provideniya
# Processing Record 28 of Set 19 | baiyin
# Processing Record 29 of Set 19 | mount vernon
# Processing Record 30 of Set 19 | puerto padre
# Processing Record 31 of Set 19 | levelland
# Processing Record 32 of Set 19 | mana
# Processing Record 33 of Set 19 | atar
# Processing Record 34 of Set 19 | aklavik
# Processing Record 35 of Set 19 | khuzhir
# Processing Record 36 of Set 19 | ailigandi
# Processing Record 37 of Set 19 | sergeyevka
# Processing Record 38 of Set 19 | broken hill
# Processing Record 39 of Set 19 | narsaq
# Processing Record 40 of Set 19 | boddam
# Processing Record 41 of Set 19 | salinopolis
# Processing Record 42 of Set 19 | westport
# Processing Record 43 of Set 19 | sorsk
# Processing Record 44 of Set 19 | narasimharajapura
# Processing Record 45 of Set 19 | vila
# Processing Record 46 of Set 19 | marathon
# Processing Record 47 of Set 19 | labrea
# Processing Record 48 of Set 19 | amderma
# City not found. Skipping...
# Processing Record 49 of Set 19 | saint-paul
# Processing Record 50 of Set 19 | mackay
# Processing Record 1 of Set 20 | ahipara
# Processing Record 2 of Set 20 | fort nelson
# Processing Record 3 of Set 20 | husavik
# Processing Record 4 of Set 20 | juli
# Processing Record 5 of Set 20 | rawson
# Processing Record 6 of Set 20 | puerto madryn
# Processing Record 7 of Set 20 | lardos
# Processing Record 8 of Set 20 | mys shmidta
# City not found. Skipping...
# Processing Record 9 of Set 20 | kota bahru
# Processing Record 10 of Set 20 | borovoy
# Processing Record 11 of Set 20 | bonoua
# Processing Record 12 of Set 20 | crab hill
# City not found. Skipping...
# Processing Record 13 of Set 20 | requena
# Processing Record 14 of Set 20 | yerbogachen
# Processing Record 15 of Set 20 | ciechocinek
# Processing Record 16 of Set 20 | road town
# Processing Record 17 of Set 20 | along
# Processing Record 18 of Set 20 | cerritos
# Processing Record 19 of Set 20 | nouadhibou
# Processing Record 20 of Set 20 | kavaratti
# Processing Record 21 of Set 20 | klaksvik
# Processing Record 22 of Set 20 | pemangkat
# Processing Record 23 of Set 20 | kimbe
# Processing Record 24 of Set 20 | severomuysk
# Processing Record 25 of Set 20 | burns lake
# Processing Record 26 of Set 20 | sosnovo-ozerskoye
# Processing Record 27 of Set 20 | luba
# Processing Record 28 of Set 20 | santa helena
# Processing Record 29 of Set 20 | paciran
# Processing Record 30 of Set 20 | nogent-le-rotrou
# Processing Record 31 of Set 20 | san policarpo
# Processing Record 32 of Set 20 | visby
# Processing Record 33 of Set 20 | ambanja
# Processing Record 34 of Set 20 | port lincoln
# Processing Record 35 of Set 20 | itoman
# Processing Record 36 of Set 20 | tura
# Processing Record 37 of Set 20 | pisco
# Processing Record 38 of Set 20 | kyshtovka
# Processing Record 39 of Set 20 | kupang
# Processing Record 40 of Set 20 | corinto
# Processing Record 41 of Set 20 | mogadishu
# Processing Record 42 of Set 20 | waldorf
# Processing Record 43 of Set 20 | vila velha
# Processing Record 44 of Set 20 | camopi
# Processing Record 45 of Set 20 | buritizeiro
# Processing Record 46 of Set 20 | saint anthony
# Processing Record 47 of Set 20 | umea
# Processing Record 48 of Set 20 | hofn
# Processing Record 49 of Set 20 | tindwari
# Processing Record 50 of Set 20 | dingle
# Processing Record 1 of Set 21 | yeppoon
# Processing Record 2 of Set 21 | flin flon
# Processing Record 3 of Set 21 | ylivieska
# Processing Record 4 of Set 21 | usinsk
# Processing Record 5 of Set 21 | sumkino
# Processing Record 6 of Set 21 | riyadh
# Processing Record 7 of Set 21 | iranshahr
# Processing Record 8 of Set 21 | chopinzinho
# Processing Record 9 of Set 21 | mgachi
# Processing Record 10 of Set 21 | roald
# Processing Record 11 of Set 21 | neuquen
# Processing Record 12 of Set 21 | mount isa
# Processing Record 13 of Set 21 | sabang
# Processing Record 14 of Set 21 | henties bay
# Processing Record 15 of Set 21 | badaojiang
# City not found. Skipping...
# Processing Record 16 of Set 21 | anar darreh
# City not found. Skipping...
# Processing Record 17 of Set 21 | ballina
# Processing Record 18 of Set 21 | jawhar
# Processing Record 19 of Set 21 | sioux lookout
# Processing Record 20 of Set 21 | atambua
# Processing Record 21 of Set 21 | ambilobe
# Processing Record 22 of Set 21 | montlucon
# Processing Record 23 of Set 21 | heilbron
# Processing Record 24 of Set 21 | caravelas
# Processing Record 25 of Set 21 | ler
# Processing Record 26 of Set 21 | fez
# Processing Record 27 of Set 21 | saint-francois
# Processing Record 28 of Set 21 | cordeiro
# Processing Record 29 of Set 21 | manggar
# Processing Record 30 of Set 21 | zavetnoye
# Processing Record 31 of Set 21 | seoul
# Processing Record 32 of Set 21 | vadso
# Processing Record 33 of Set 21 | terra santa
# Processing Record 34 of Set 21 | half moon bay
# Processing Record 35 of Set 21 | ilebo
# Processing Record 36 of Set 21 | soubre
# Processing Record 37 of Set 21 | cururupu
# Processing Record 38 of Set 21 | skelleftea
# Processing Record 39 of Set 21 | shestakovo
# Processing Record 40 of Set 21 | redlands
# Processing Record 41 of Set 21 | rungata
# City not found. Skipping...
# Processing Record 42 of Set 21 | chicaman
# Processing Record 43 of Set 21 | acajutla
# Processing Record 44 of Set 21 | sena madureira
# Processing Record 45 of Set 21 | padang
# Processing Record 46 of Set 21 | vanimo
# Processing Record 47 of Set 21 | cobija
# Processing Record 48 of Set 21 | san quintin
# Processing Record 49 of Set 21 | berlevag
# Processing Record 50 of Set 21 | saskylakh
# Processing Record 1 of Set 22 | santa rosa
# Processing Record 2 of Set 22 | priego de cordoba
# Processing Record 3 of Set 22 | susangerd
# Processing Record 4 of Set 22 | ulaangom
# Processing Record 5 of Set 22 | cajabamba
# Processing Record 6 of Set 22 | shelburne
# Processing Record 7 of Set 22 | luanda
# Processing Record 8 of Set 22 | trelew
# Processing Record 9 of Set 22 | newport
# Processing Record 10 of Set 22 | ust-ishim
# Processing Record 11 of Set 22 | hovd
# Processing Record 12 of Set 22 | baykit
# Processing Record 13 of Set 22 | naze
# Processing Record 14 of Set 22 | am timan
# Processing Record 15 of Set 22 | tual
# Processing Record 16 of Set 22 | samarai
# Processing Record 17 of Set 22 | alvaraes
# Processing Record 18 of Set 22 | calatayud
# Processing Record 19 of Set 22 | saint-denis
# Processing Record 20 of Set 22 | grand gaube
# Processing Record 21 of Set 22 | huai yot
# Processing Record 22 of Set 22 | lata
# Processing Record 23 of Set 22 | gillette
# Processing Record 24 of Set 22 | san cristobal
# Processing Record 25 of Set 22 | ngukurr
# City not found. Skipping...
# Processing Record 26 of Set 22 | saldanha
# Processing Record 27 of Set 22 | dymer
# Processing Record 28 of Set 22 | edd
# Processing Record 29 of Set 22 | dekoa
# City not found. Skipping...
# Processing Record 30 of Set 22 | kargasok
# Processing Record 31 of Set 22 | grand centre
# City not found. Skipping...
# Processing Record 32 of Set 22 | batagay-alyta
# Processing Record 33 of Set 22 | gravdal
# Processing Record 34 of Set 22 | delta del tigre
# Processing Record 35 of Set 22 | south lake tahoe
# Processing Record 36 of Set 22 | kozelsk
# Processing Record 37 of Set 22 | kirakira
# Processing Record 38 of Set 22 | umtata
# Processing Record 39 of Set 22 | amasia
# Processing Record 40 of Set 22 | antofagasta
# Processing Record 41 of Set 22 | saint-raymond
# Processing Record 42 of Set 22 | kulhudhuffushi
# Processing Record 43 of Set 22 | malakwal
# Processing Record 44 of Set 22 | la crosse
# Processing Record 45 of Set 22 | palabuhanratu
# City not found. Skipping...
# Processing Record 46 of Set 22 | sakakah
# Processing Record 47 of Set 22 | pedro carbo
# Processing Record 48 of Set 22 | faxinal
# Processing Record 49 of Set 22 | acarau
# Processing Record 50 of Set 22 | sitka
# Processing Record 1 of Set 23 | luderitz
# Processing Record 2 of Set 23 | makat
# Processing Record 3 of Set 23 | flinders
# Processing Record 4 of Set 23 | kyzyl-suu
# Processing Record 5 of Set 23 | fayaoue
# Processing Record 6 of Set 23 | rurrenabaque
# Processing Record 7 of Set 23 | bolungarvik
# City not found. Skipping...
# Processing Record 8 of Set 23 | barabinsk
# Processing Record 9 of Set 23 | aquiraz
# Processing Record 10 of Set 23 | ayabaca
# Processing Record 11 of Set 23 | tiarei
# Processing Record 12 of Set 23 | ayni
# Processing Record 13 of Set 23 | canmore
# Processing Record 14 of Set 23 | milton
# Processing Record 15 of Set 23 | isagarh
# Processing Record 16 of Set 23 | cruden bay
# City not found. Skipping...
# Processing Record 17 of Set 23 | achisay
# City not found. Skipping...
# Processing Record 18 of Set 23 | beloha
# Processing Record 19 of Set 23 | marienburg
# Processing Record 20 of Set 23 | margate
# Processing Record 21 of Set 23 | havelock
# Processing Record 22 of Set 23 | qasigiannguit
# Processing Record 23 of Set 23 | kharhial
# Processing Record 24 of Set 23 | port-cartier
# Processing Record 25 of Set 23 | kattivakkam
# Processing Record 26 of Set 23 | vanavara
# Processing Record 27 of Set 23 | coquimbo
# Processing Record 28 of Set 23 | nelson bay
# Processing Record 29 of Set 23 | mayo
# Processing Record 30 of Set 23 | high rock
# Processing Record 31 of Set 23 | abu dhabi
# Processing Record 32 of Set 23 | mersing
# Processing Record 33 of Set 23 | nizwa
# Processing Record 34 of Set 23 | ballitoville
# Processing Record 35 of Set 23 | la ronge
# Processing Record 36 of Set 23 | severodvinsk
# Processing Record 37 of Set 23 | yamada
# Processing Record 38 of Set 23 | gujranwala
# Processing Record 39 of Set 23 | grao mogol
# Processing Record 40 of Set 23 | bahjoi
# Processing Record 41 of Set 23 | shihezi
# Processing Record 42 of Set 23 | halifax
# Processing Record 43 of Set 23 | carutapera
# Processing Record 44 of Set 23 | maniwaki
# Processing Record 45 of Set 23 | virginia beach
# Processing Record 46 of Set 23 | comodoro rivadavia
# Processing Record 47 of Set 23 | gherghesti
# Processing Record 48 of Set 23 | kahta

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import the time module.
import time
# Get today's date in seconds.
today = time.strftime("%x")
today

# %%
# Import time module
import time

# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()

# %%
# Import linear regression from the SciPy stats module.
from scipy.stats import linregress

# %%
# Create an equal number of latitudes and temperatures.
lats = [42.5, 43.9, 8.1, 36.8, 79.9, 69.1, 25.7, 15.3, 12.7, 64.5]
temps = [80.5, 75.3, 90.9, 90.0, 40.4, 62.3, 85.4, 79.6, 72.5, 72.0]

# %%
# Perform linear regression.
(slope, intercept, r_value, p_value, std_err) = linregress(lats, temps)
# Get the equation of the line.
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
print(f"The p-value is: {p_value:.3f}")

# %%
# Calculate the regression line "y values" from the slope and intercept.
regress_values = [(lat * slope + intercept) for lat in lats]

# %%
# Import Matplotlib.
import matplotlib.pyplot as plt
# Create a scatter plot of the x and y values.
plt.scatter(lats,temps)
# Plot the regression line with the x-values and the y coordinates based on the intercept and slope.
plt.plot(lats,regress_values,"r")
# Annotate the text for the line equation and add its coordinates.
plt.annotate(line_eq, (10,40), fontsize=15, color="red")
plt.xlabel('Latitude')
plt.ylabel('Temp')
plt.show()

# %%
# Import linregress
from scipy.stats import linregress

# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):

    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
index13 = city_data_df.loc[13] 
index13

# %%
city_data_df["Lat"] >= 0

# %%
city_data_df.loc[(city_data_df["Lat"] >= 0)].head()

# %%
# Create Northern and Southern Hemisphere DataFrames.
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(10,40))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(-50,90))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for % Humidity', '% Humidity',(40,10))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                       for % Humidity', '% Humidity',(-50,15))

# %%
# SKILL DRILL Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
# Call the function
plot_linear_regression(x_values, y_values,
                   'Linear Regression on the Northern Hemisphere \
                    for % Cloudiness', '% Cloudiness',(10,55))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for % Cloudiness', '% Cloudiness',(-50,60))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Wind Speed', 'Wind Speed',(40,35))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for Wind Speed', 'Wind Speed',(-50,35))

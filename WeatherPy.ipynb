# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Out:
# rikitea pf
# ushuaia ar
# homer us
# batagay ru
# arman ru
# skjervoy no
# avarua ck
# punta arenas cl
# dikson ru
# goundam ml
# bengkulu id
# quatre cocos mu
# caravelas br
# codrington ag
# cape town za
# ushuaia ar
# butaritari ki
# rikitea pf
# taolanaro mg
# jamestown sh
# te anau nz
# lagoa pt
# punta arenas cl
# bolshaya irba ru
# mastung pk
# bredasdorp za
# yarada in
# biak id
# saint-philippe re
# kavieng pg
# ushuaia ar
# parvatipuram in
# tecoanapa mx
# khash ir
# souillac mu
# tuktoyaktuk ca
# punta arenas cl
# hilo us
# mys shmidta ru
# taolanaro mg
# sirjan ir
# arraial do cabo br
# sorland no
# upernavik gl
# bredasdorp za
# cidreira br
# saint-philippe re
# alangayam in
# bluff nz
# rikitea pf
# chicama pe
# cabo rojo us
# cabo san lucas mx
# atambua id
# soe id
# flinders au
# ponta do sol pt
# doha qa
# vaini to
# bluff nz
# beringen lu
# lashio mm
# burica pa
# narsaq gl
# kortkeros ru
# jamestown sh
# lakselv no
# rikitea pf
# nemuro jp
# poso id
# punta arenas cl
# beloha mg
# sentyabrskiy ru
# pangnirtung ca
# biak id
# butaritari ki
# haines junction ca
# hamilton bm
# tuatapere nz
# torbay ca
# kamenka ru
# vilhena br
# laguna br
# taolanaro mg
# kapaa us
# longyearbyen sj
# bredasdorp za
# tay ninh vn
# spassk ru
# ust-maya ru
# araouane ml
# saldanha za
# okandja ga
# yellowknife ca
# port alfred za
# karasburg na
# puerto ayora ec
# torbay ca
# albany au
# ushuaia ar
# todos santos mx
# carnarvon au
# yumen cn
# upernavik gl
# port alfred za
# urusha ru
# barrow us
# lompoc us
# geresk af
# rikitea pf
# kapaa us
# qaanaaq gl
# sergeyevka kz
# upernavik gl
# taolanaro mg
# qui nhon vn
# puerto ayora ec
# albany au
# upernavik gl
# cookshire ca
# punta arenas cl
# puerto cabezas ni
# aitape pg
# rikitea pf
# albany au
# hobart au
# jaguariaiva br
# rikitea pf
# kavieng pg
# east london za
# salta ar
# quatre cocos mu
# cherskiy ru
# longyearbyen sj
# poum nc
# castro cl
# olafsvik is
# vaitupu wf
# chumikan ru
# dunedin nz
# saskylakh ru
# lake wales us
# tirano it
# klaksvik fo
# belushya guba ru
# miri my
# batagay-alyta ru
# ribeira grande pt
# rikitea pf
# yarada in
# avarua ck
# mataura pf
# ribeira grande pt
# muli mv
# neiafu to
# butaritari ki
# thompson ca
# tessalit ml
# katsuura jp
# faya td
# neuquen ar
# beira mz
# busselton au
# puerto ayora ec
# busselton au
# khatanga ru
# saskylakh ru
# thompson ca
# tuktoyaktuk ca
# kapaa us
# atuona pf
# tiksi ru
# albany au
# hamilton bm
# avarua ck
# puerto ayora ec
# punta arenas cl
# racconigi it
# huangzhai cn
# nagua do
# pisco pe
# chuy uy
# hobart au
# kearney us
# susanino ru
# semey kz
# yellowknife ca
# nguiu au
# shaartuz tj
# yellowknife ca
# hovd mn
# margate za
# havre-saint-pierre ca
# palmer us
# mataura pf
# mys shmidta ru
# rikitea pf
# dikson ru
# lebu cl
# kangaatsiaq gl
# qaanaaq gl
# cape town za
# port elizabeth za
# rikitea pf
# russell nz
# kaoma zm
# lata sb
# kazerun ir
# severo-kurilsk ru
# mataura pf
# bethel us
# puerto ayora ec
# ribeira grande pt
# punta arenas cl
# kenitra ma
# punta arenas cl
# ushuaia ar
# cabo san lucas mx
# okato nz
# cape town za
# cape town za
# upernavik gl
# marzuq ly
# chuy uy
# kapaa us
# bredasdorp za
# kashary ru
# saint-pierre re
# cape town za
# ust-omchug ru
# mataura pf
# lebu cl
# mataura pf
# hithadhoo mv
# cherskiy ru
# woodward us
# bethel us
# kyzyl-suu kg
# nome us
# lorengau pg
# tessalit ml
# donskoye ru
# daru pg
# busselton au
# makokou ga
# revelstoke ca
# hermanus za
# gat ly
# chuy uy
# rikitea pf
# port blair in
# airai pw
# ushuaia ar
# qaanaaq gl
# rikitea pf
# coihaique cl
# amderma ru
# puerto ayora ec
# qaanaaq gl
# dingle ie
# yerbogachen ru
# east london za
# miguel hidalgo mx
# punta arenas cl
# saskylakh ru
# palabuhanratu id
# tasiilaq gl
# novikovo ru
# mys shmidta ru
# albany au
# punta arenas cl
# muisne ec
# saint george bm
# attawapiskat ca
# ribeira grande pt
# berdigestyakh ru
# bluff nz
# qaanaaq gl
# kununurra au
# praia da vitoria pt
# busselton au
# dikson ru
# tallahassee us
# bambous virieux mu
# mataura pf
# jamestown sh
# tuatapere nz
# albany au
# iqaluit ca
# hualmay pe
# mar del plata ar
# kapaa us
# praia da vitoria pt
# krasnoselkup ru
# storslett no
# atuona pf
# airai pw
# porto novo cv
# ushuaia ar
# albany au
# vaini to
# carnarvon au
# tasiilaq gl
# atuona pf
# cherskiy ru
# yerbogachen ru
# port shepstone za
# illoqqortoormiut gl
# takaka nz
# isangel vu
# kushima jp
# pyapon mm
# rikitea pf
# albany au
# ushuaia ar
# punta arenas cl
# aland in
# avera pf
# barawe so
# bluff nz
# norman wells ca
# rikitea pf
# burnham nz
# caraquet ca
# souillac mu
# aksu cn
# namibe ao
# tena ec
# krizevci hr
# ahipara nz
# bethel us
# yellowknife ca
# barentsburg sj
# illoqqortoormiut gl
# hilo us
# butaritari ki
# barrow us
# thompson ca
# evensk ru
# lata sb
# ilulissat gl
# urumqi cn
# artyk ru
# ushuaia ar
# axim gh
# saint-philippe re
# ojinaga mx
# nikolskoye ru
# illoqqortoormiut gl
# castro cl
# punta arenas cl
# bredasdorp za
# ushuaia ar
# castro cl
# san patricio mx
# qazvin ir
# thompson ca
# mataura pf
# saint-philippe re
# khandyga ru
# baturaja id
# nikolskoye ru
# gravdal no
# cape town za
# puerto ayora ec
# saint-philippe re
# harper lr
# saint-philippe re
# wahran dz
# nikolskoye ru
# mataura pf
# tutoia br
# barentsburg sj
# thompson ca
# laguna br
# hamilton bm
# dingle ie
# vila velha br
# wajir ke
# grand-lahou ci
# bluff nz
# qaanaaq gl
# chokurdakh ru
# puerto ayora ec
# shieli kz
# albany au
# asau tv
# saint anthony ca
# mahibadhoo mv
# ilulissat gl
# rikitea pf
# luderitz na
# bethanien na
# esperance au
# punta arenas cl
# ushuaia ar
# ushuaia ar
# kapaa us
# vaini to
# laguna br
# mys shmidta ru
# los llanos de aridane es
# barrow us
# kazerun ir
# nanortalik gl
# hobyo so
# hami cn
# nikolskoye ru
# east london za
# san andres co
# ponta do sol cv
# amderma ru
# guerrero negro mx
# bluff nz
# negele et
# avarua ck
# mataura pf
# chengde cn
# busselton au
# shirokiy ru
# ponta do sol pt
# mataura pf
# marawi sd
# attawapiskat ca
# rikitea pf
# owando cg
# busselton au
# illoqqortoormiut gl
# te anau nz
# kununurra au
# hamilton bm
# coro ve
# barentsburg sj
# longyearbyen sj
# provideniya ru
# ilebo cd
# albany au
# harnosand se
# bellavista pe
# port alfred za
# husavik is
# butaritari ki
# aklavik ca
# airai pw
# chapais ca
# bethel us
# sioux lookout ca
# opunake nz
# poso id
# clyde river ca
# siparia tt
# illoqqortoormiut gl
# victoria sc
# bundaberg au
# jamestown sh
# busselton au
# punta arenas cl
# nayoro jp
# barrow us
# ushuaia ar
# siniscola it
# amderma ru
# busselton au
# tommot ru
# upernavik gl
# portland au
# avarua ck
# bambous virieux mu
# punta arenas cl
# dikson ru
# hermanus za
# belaya gora ru
# severo-kurilsk ru
# hobart au
# lompoc us
# upernavik gl
# berdigestyakh ru
# jadu ly
# vaini to
# pathein mm
# cape town za
# belushya guba ru
# diffa ne
# barentsburg sj
# hobyo so
# riyadh sa
# san quintin mx
# kapaa us
# vaini to
# nouadhibou mr
# sol-iletsk ru
# busselton au
# arraial do cabo br
# le port re
# maridi sd
# ilulissat gl
# dikson ru
# bredasdorp za
# barrow us
# port alfred za
# bargal so
# busselton au
# fortuna us
# tilichiki ru
# avarua ck
# kapaa us
# norman wells ca
# saint-joseph re
# itoman jp
# norman wells ca
# ushuaia ar
# albany au
# kieta pg
# namibe ao
# barrow us
# busselton au
# ushuaia ar
# rincon an
# mataura pf
# mataura pf
# fayaoue nc
# cape town za
# san cristobal ec
# bredasdorp za
# manacapuru br
# arraial do cabo br
# saleaula ws
# east london za
# lampang th
# new norfolk au
# georgetown sh
# tanabe jp
# atuona pf
# puerto ayora ec
# aklavik ca
# kaitangata nz
# cidreira br
# vaini to
# hermanus za
# longyearbyen sj
# punta arenas cl
# puerto ayora ec
# severo-kurilsk ru
# malatya tr
# jamestown sh
# nizhneyansk ru
# saint george bm
# bathsheba bb
# lavrentiya ru
# rikitea pf
# mataura pf
# marrakesh ma
# sistranda no
# ponta do sol cv
# mataura pf
# punta arenas cl
# takoradi gh
# pangnirtung ca
# ushuaia ar
# yellowknife ca
# kapaa us
# butaritari ki
# rikitea pf
# hermanus za
# butaritari ki
# hilo us
# trudarmeyskiy ru
# guerrero negro mx
# salalah om
# puerto leguizamo co
# sargur in
# saint george bm
# tygda ru
# khatanga ru
# port alfred za
# lagoa pt
# rikitea pf
# avarua ck
# new norfolk au
# yulara au
# tasiilaq gl
# nizhneyansk ru
# cape town za
# rio novo do sul br
# hithadhoo mv
# albany au
# upernavik gl
# nikolskoye ru
# tuktoyaktuk ca
# taolanaro mg
# troy us
# taolanaro mg
# thompson ca
# puerto ayora ec
# hobart au
# lagoa pt
# esperance au
# east london za
# makat kz
# bouna ci
# toppenish us
# port alfred za
# fexhe-le-haut-clocher be
# darnah ly
# eureka us
# te anau nz
# barrow us
# sao gabriel da cachoeira br
# rikitea pf
# del rio us
# rikitea pf
# kapaa us
# cherskiy ru
# mitu co
# chumikan ru
# hilo us
# tuktoyaktuk ca
# xining cn
# rikitea pf
# zhangjiakou cn
# jamestown sh
# stokmarknes no
# beringovskiy ru
# punta arenas cl
# rikitea pf
# rikitea pf
# bolungarvik is
# piacabucu br
# bengkulu id
# varzea alegre br
# uroteppa tj
# cape town za
# barrow us
# albany au
# grindavik is
# dhanera in
# canton us
# komsomolskiy ru
# port alfred za
# naze jp
# atuona pf
# vaini to
# puerto ayora ec
# meulaboh id
# camacha pt
# torbay ca
# new norfolk au
# samusu ws
# trinidad bo
# barrow us
# abu dhabi ae
# salamiyah sy
# barentsburg sj
# ushuaia ar
# butaritari ki
# rikitea pf
# waw sd
# ushuaia ar
# guerrero negro mx
# america dourada br
# cabo san lucas mx
# marcona pe
# atuona pf
# ushuaia ar
# georgetown sh
# ushuaia ar
# saint-philippe re
# ushuaia ar
# hithadhoo mv
# busselton au
# vila velha br
# fort saint john ca
# bluff nz
# rikitea pf
# chuy uy
# margate za
# port alfred za
# tuktoyaktuk ca
# sampit id
# itarema br
# khatanga ru
# rikitea pf
# ostrovnoy ru
# new norfolk au
# busselton au
# albany au
# port elizabeth za
# broome au
# hihifo to
# teknaf bd
# ahuimanu us
# praia da vitoria pt
# saskylakh ru
# ribeira grande pt
# nantucket us
# bluff nz
# arraial do cabo br
# severo-kurilsk ru
# yinchuan cn
# venice us
# seoul kr
# humaita br
# severo-kurilsk ru
# sao filipe cv
# kabin buri th
# aripuana br
# saldanha za
# sur om
# rikitea pf
# wonthaggi au
# torbay ca
# new norfolk au
# butaritari ki
# upernavik gl
# atuona pf
# vaini to
# bubaque gw
# ilulissat gl
# tigil ru
# saleaula ws
# atuona pf
# tuatapere nz
# faya td
# kapaa us
# greenville us
# menongue ao
# klaksvik fo
# busselton au
# cape town za
# saint-philippe re
# emerald au
# mataura pf
# bluff nz
# yellowknife ca
# zhangye cn
# pisco pe
# hilo us
# kapaa us
# port alfred za
# vaini to
# puerto colombia co
# bozeman us
# kavaratti in
# hermanus za
# saint-lo fr
# port elizabeth za
# saint-philippe re
# qaanaaq gl
# payakumbuh id
# albany au
# arman ru
# langxiang cn
# manyana bw
# yerbogachen ru
# yellowknife ca
# kapaa us
# rikitea pf
# busselton au
# dikson ru
# cehegin es
# saint-philippe re
# havre-saint-pierre ca
# nhulunbuy au
# bur gabo so
# albany au
# kloulklubed pw
# shenjiamen cn
# satitoa ws
# las cruces us
# codrington ag
# ichinohe jp
# upernavik gl
# olafsvik is
# albany au
# bredasdorp za
# ushuaia ar
# margate za
# milas tr
# hervey bay au
# yellowknife ca
# khatanga ru
# puerto ayora ec
# villarrica cl
# mahebourg mu
# makurdi ng
# mar del plata ar
# busselton au
# east london za
# vila franca do campo pt
# port elizabeth za
# wichita falls us
# san quintin mx
# vaitupu wf
# pevek ru
# hobart au
# tokur ru
# samarai pg
# fortuna us
# ushuaia ar
# marion us
# saskylakh ru
# pangnirtung ca
# lasa cn
# ushuaia ar
# punta arenas cl
# ushuaia ar
# saldanha za
# acapulco mx
# albany au
# sandwich us
# punta arenas cl
# pokrovsk-uralskiy ru
# yellowknife ca
# puerto ayora ec
# padang id
# busselton au
# san jose gt
# albany au
# plattling de
# labytnangi ru
# yaan cn
# ponta do sol cv
# rawson ar
# bilibino ru
# chapayevka ua
# sabya sa
# ponta do sol cv
# charters towers au
# butaritari ki
# provideniya ru
# comodoro rivadavia ar
# coahuayana mx
# qaanaaq gl
# culfa az
# mar del plata ar
# tomatlan mx
# mataura pf
# mavrovi anovi mk
# victoria sc
# bengkulu id
# rikitea pf
# punta arenas cl
# albany au
# george za
# kushiro jp
# rikitea pf
# cidreira br
# ushuaia ar
# dvinskoy ru
# cabedelo br
# cape town za
# port hardy ca
# kalmunai lk
# puerto ayora ec
# emerald au
# lamar us
# ushuaia ar
# chicama pe
# attawapiskat ca
# jamestown sh
# kapaa us
# barentsburg sj
# busselton au
# port alfred za
# ushuaia ar
# yellowknife ca
# new norfolk au
# mbale ug
# busselton au
# samusu ws
# petauke zm
# avarua ck
# albany au
# warqla dz
# trat th
# eureka us
# esso ru
# mount gambier au
# taolanaro mg
# barrow us
# palabuhanratu id
# yining cn
# coihaique cl
# ushuaia ar
# fukue jp
# faya td
# albany au
# puerto ayora ec
# bredasdorp za
# denpasar id
# ngukurr au
# kaitangata nz
# bambous virieux mu
# east london za
# leningradskiy ru
# ushuaia ar
# torbay ca
# los llanos de aridane es
# saint anthony ca
# muchkapskiy ru
# vaini to
# grand river south east mu
# albany au
# toora-khem ru
# hithadhoo mv
# sabang id
# naze jp
# saskylakh ru
# castro cl
# albany au
# ryazanovskiy ru
# mataura pf
# praia cv
# acarau br
# ribeira grande pt
# east london za
# attawapiskat ca
# port alfred za
# mataura pf
# egvekinot ru
# guerrero negro mx
# cape town za
# tuktoyaktuk ca
# qaanaaq gl
# tsihombe mg
# hilo us
# joshimath in
# novyy urgal ru
# padang id
# marcona pe
# punta arenas cl
# taolanaro mg
# ushuaia ar
# goderich sl
# stephenville us
# los llanos de aridane es
# kavieng pg
# cockburn town tc
# barentsburg sj
# rikitea pf
# sao filipe cv
# iskateley ru
# saint-pierre pm
# jalu ly
# okato nz
# avarua ck
# kapaa us
# bambous virieux mu
# new norfolk au
# bila tserkva ua
# bredasdorp za
# talaya ru
# corinth us
# licata it
# punta arenas cl
# half moon bay us
# lebu cl
# cabo san lucas mx
# yashkul ru
# boralday kz
# mar del plata ar
# punta arenas cl
# longyearbyen sj
# faanui pf
# souillac mu
# avarua ck
# mataura pf
# ushuaia ar
# boa vista br
# pergamino ar
# avarua ck
# moron mn
# laguna br
# punta arenas cl
# ballina au
# waddan ly
# barrow us
# ushuaia ar
# hambantota lk
# mataura pf
# hervey bay au
# zhigansk ru
# acarau br
# ngukurr au
# qaanaaq gl
# waverly us
# busselton au
# rikitea pf
# lasa cn
# albany au
# upernavik gl
# cherskiy ru
# thompson ca
# rundu na
# chihuahua mx
# taltal cl
# hithadhoo mv
# ushuaia ar
# bluff nz
# hermanus za
# north platte us
# atuona pf
# carnarvon au
# kodiak us
# bethel us
# clyde river ca
# leningradskiy ru
# butaritari ki
# mataura pf
# thompson ca
# port alfred za
# vaini to
# olafsvik is
# upernavik gl
# hermanus za
# sorland no
# heishan cn
# upernavik gl
# mataura pf
# floro no
# karaul ru
# klyuchi ru
# cape town za
# ribeira grande pt
# salalah om
# pingzhuang cn
# kathu th
# saldanha za
# mahalingpur in
# touros br
# mataura pf
# coquimbo cl
# cabedelo br
# portland au
# hobart au
# tura ru
# carnarvon au
# mataura pf
# bethel us
# hilo us
# vaini to
# neryungri ru
# sur om
# hermanus za
# ushuaia ar
# manta ec
# saint-joseph re
# punta arenas cl
# beboto td
# georgetown sh
# lengshuitan cn
# yellowknife ca
# barentsburg sj
# fonte boa br
# tiksi ru
# saint anthony ca
# skjervoy no
# san patricio mx
# minab ir
# nikolskoye ru
# mushie cd
# severo-kurilsk ru
# atuona pf
# busselton au
# vaini to
# ballinrobe ie
# hithadhoo mv
# bredasdorp za
# sidrolandia br
# talnakh ru
# cape town za
# ponta do sol cv
# sarkand kz
# chiang klang th
# ngunguru nz
# bonthe sl
# flinders au
# auxerre fr
# puri in
# qaanaaq gl
# mar del plata ar
# praia cv
# rundu na
# tuatapere nz
# rikitea pf
# butaritari ki
# vaini to
# hermanus za
# nuevo laredo mx
# amderma ru
# haibowan cn
# rikitea pf
# mount gambier au
# pisco pe
# jamestown sh
# punta arenas cl
# rikitea pf
# punta arenas cl
# gorontalo id
# rikitea pf
# samusu ws
# mataura pf
# saldanha za
# torbay ca
# cherskiy ru
# ushuaia ar
# duverge do
# comodoro rivadavia ar
# lima pe
# meulaboh id
# pisco pe
# coban gt
# cabo san lucas mx
# nioro ml
# albany au
# haines junction ca
# jamestown sh
# hermanus za
# temaraia ki
# cape town za
# punta arenas cl
# san quintin mx
# erdenet mn
# rikitea pf
# ushuaia ar
# kaitangata nz
# ushuaia ar
# atuona pf
# cape town za
# hermanus za
# khatanga ru
# casale monferrato it
# kavaratti in
# rikitea pf
# taolanaro mg
# vardo no
# lavrentiya ru
# puerto ayora ec
# tias es
# vestmannaeyjar is
# saint-philippe re
# port-cartier ca
# luderitz na
# talnakh ru
# igurubi tz
# carnarvon au
# bowen au
# villa corzo mx
# mataura pf
# tonekabon ir
# port lincoln au
# bluff nz
# vaini to
# ushuaia ar
# butaritari ki
# busselton au
# cidreira br
# belushya guba ru
# tiksi ru
# tombouctou ml
# fortuna us
# taolanaro mg
# upernavik gl
# busselton au
# alice springs au
# fukue jp
# ambon id
# hamilton bm
# tiksi ru
# torbay ca
# saubara br
# illoqqortoormiut gl
# rikitea pf
# mitsamiouli km
# atuona pf
# vestmannaeyjar is
# saint-augustin ca
# albany au
# mahajanga mg
# cape town za
# hobyo so
# georgetown sh
# taolanaro mg
# mys shmidta ru
# bethel us
# changli cn
# nizhneyansk ru
# rikitea pf
# bredasdorp za
# the valley ai
# rikitea pf
# ulaangom mn
# ushuaia ar
# poum nc
# karatau kz
# tuktoyaktuk ca
# cradock za
# nishihara jp
# rikitea pf
# busselton au
# albany au
# caraballeda ve
# augusto correa br
# nouadhibou mr
# chuy uy
# chuy uy
# auki sb
# punta arenas cl
# port lincoln au
# new norfolk au
# lebu cl
# saint anthony ca
# karratha au
# punta arenas cl
# plettenberg bay za
# khatanga ru
# new norfolk au
# busselton au
# barrow us
# iida jp
# batagay-alyta ru
# mezen ru
# acapulco mx
# azuaga es
# bluff nz
# cockburn town tc
# illoqqortoormiut gl
# toliary mg
# katesh tz
# bridlington gb
# illoqqortoormiut gl
# jutai br
# kloulklubed pw
# berezovyy ru
# avarua ck
# guarapari br
# barentsburg sj
# katangli ru
# garden city us
# lebu cl
# rikitea pf
# ngukurr au
# hilo us
# zhanatas kz
# mbandaka cd
# east london za
# barrow us
# revyakino ru
# east london za
# lagoa pt
# mtwara tz
# busselton au
# khatanga ru
# rikitea pf
# taltal cl
# mataura pf
# rungata ki
# rikitea pf
# ushuaia ar
# ribeira grande pt
# ponta do sol cv
# kavieng pg
# saint anthony ca
# rikitea pf
# kawana waters au
# sansepolcro it
# hobart au
# wilmington us
# taolanaro mg
# butaritari ki
# kresttsy ru
# coihaique cl
# a dos cunhados pt
# carnarvon au
# hilo us
# atuona pf
# ushuaia ar
# khatanga ru
# samusu ws
# taolanaro mg
# aripuana br
# kapaa us
# mahebourg mu
# vulcanesti md
# sentyabrskiy ru
# saskylakh ru
# mahadday weyne so
# saint-augustin ca
# mataura pf
# rikitea pf
# bargal so
# severo-kurilsk ru
# cape town za
# hobart au
# chuy uy
# kapaa us
# kodiak us
# barrow us
# hithadhoo mv
# vila franca do campo pt
# cairns au
# mersin tr
# praya id
# jamestown sh
# isangel vu
# elliot lake ca
# hohhot cn
# victoria sc
# qaanaaq gl
# nizhneyansk ru
# lubbock us
# kingaroy au
# ushuaia ar
# saskylakh ru
# jamestown sh
# busselton au
# taolanaro mg
# college us
# ushuaia ar
# bluff nz
# itoigawa jp
# jamestown sh
# port alfred za
# hilo us
# jamestown sh
# busselton au
# butaritari ki
# yongan cn
# doctor pedro p. pena py
# seydi tm
# umm ruwabah sd
# naze jp
# fairbanks us
# gamba ga
# natal br
# yenagoa ng
# yellowknife ca
# havre-saint-pierre ca
# qaanaaq gl
# hermanus za
# dalnegorsk ru
# punta arenas cl
# hamilton bm
# bredasdorp za
# mataura pf
# krasnoselkup ru
# sentyabrskiy ru
# cape town za
# bluff nz
# otane nz
# ushuaia ar
# blackwater au
# bredasdorp za
# bouloupari nc
# ghanzi bw
# coihaique cl
# jamestown sh
# vaini to
# port alfred za
# puerto ayora ec
# lompoc us
# el bagre co
# aklavik ca
# kapaa us
# bluff nz
# guerrero negro mx
# nanortalik gl
# cabo san lucas mx
# nome us
# cape town za
# albany au
# atuona pf
# hilo us
# east london za
# smithers ca
# albany au
# mataura pf
# mumford gh
# barrow us
# kimberley za
# chokurdakh ru
# mar del plata ar
# bethel us
# port hardy ca
# vaitupu wf
# rikitea pf
# tarudant ma
# saint-philippe re
# rikitea pf
# acapulco mx
# avarua ck
# illoqqortoormiut gl
# rikitea pf
# samarkand uz
# cape town za
# kano ng
# saint-philippe re
# busselton au
# chokurdakh ru
# dikson ru
# komsomolskiy ru
# mahebourg mu
# tobane bw
# rikitea pf
# severo-kurilsk ru
# jamestown sh
# tiksi ru
# nizhniy odes ru
# okhotsk ru
# ishigaki jp
# chokurdakh ru
# kodiak us
# hermanus za
# iqaluit ca
# busselton au
# ballina ie
# cape town za
# saint-pierre pm
# cape town za
# avarua ck
# sangar ru
# bahia de caraquez ec
# tiksi ru
# taikang cn
# port-gentil ga
# nemuro jp
# chokurdakh ru
# havoysund no
# plomarion gr
# rikitea pf
# talnakh ru
# mahebourg mu
# oksfjord no
# okhotsk ru
# samusu ws
# east london za
# albany au
# ushuaia ar
# cape town za
# puerto ayora ec
# saint anthony ca
# korla cn
# kodiak us
# vaini to
# vangaindrano mg
# albany au
# trebisacce it
# taolanaro mg
# rikitea pf
# busselton au
# rikitea pf
# rikitea pf
# chuy uy
# mataura pf
# tumannyy ru
# saint-junien fr
# hami cn
# sao joao da barra br
# rikitea pf
# nizhniy baskunchak ru
# punta arenas cl
# hermanus za
# maragogi br
# alegrete br
# sakakah sa
# yellowknife ca
# talnakh ru
# mataura pf
# busselton au
# kahului us
# sentyabrskiy ru
# yatou cn
# ushuaia ar
# mataura pf
# chuy uy
# rawah iq
# rikitea pf
# bardstown us
# bolshoye sorokino ru
# mataura pf
# puerto ayora ec
# punta arenas cl
# provideniya ru
# miquelon pm
# qaanaaq gl
# barrow us
# abrau-dyurso ru
# ushuaia ar
# winsum nl
# samusu ws
# houma us
# port elizabeth za
# mandalgovi mn
# rikitea pf
# cape town za
# japura br
# pisco pe
# taolanaro mg
# rikitea pf
# ushuaia ar

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 606

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c8cc1f77bc87360422ad5bbb278cce61

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c8cc1f77bc87360422ad5bbb278cce61&q=Boston

# %%
# Make a 'Get' request for the city weather.
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Get the text of the 'Get' request.
city_weather.text
# Out:
# '{"coord":{"lon":-71.0598,"lat":42.3584},"weather":[{"id":802,"main":"Clouds","description":"scattered clouds","icon":"03n"}],"base":"stations","main":{"temp":28.53,"feels_like":19.69,"temp_min":25,"temp_max":32,"pressure":1025,"humidity":51},"visibility":10000,"wind":{"speed":5.75,"deg":310},"clouds":{"all":40},"dt":1610335832,"sys":{"type":1,"id":3486,"country":"US","sunrise":1610280748,"sunset":1610314252},"timezone":-18000,"id":4930956,"name":"Boston","cod":200}'

# %%
# Get the JSON text of the 'Get' request.
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 802,
#    'main': 'Clouds',
#    'description': 'scattered clouds',
#    'icon': '03n'}],
#  'base': 'stations',
#  'main': {'temp': 28.53,
#   'feels_like': 19.69,
#   'temp_min': 25,
#   'temp_max': 32,
#   'pressure': 1025,
#   'humidity': 51},
#  'visibility': 10000,
#  'wind': {'speed': 5.75, 'deg': 310},
#  'clouds': {'all': 40},
#  'dt': 1610335832,
#  'sys': {'type': 1,
#   'id': 3486,
#   'country': 'US',
#   'sunrise': 1610280748,
#   'sunset': 1610314252},
#  'timezone': -18000,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City Weather found.

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Bston"
city_weather = requests.get(city_url)
if city_weather.json():
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City Weather found.

# %%
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c8cc1f77bc87360422ad5bbb278cce61&q=Bston

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 802,
#    'main': 'Clouds',
#    'description': 'scattered clouds',
#    'icon': '03n'}],
#  'base': 'stations',
#  'main': {'temp': 28.53,
#   'feels_like': 19.69,
#   'temp_min': 25,
#   'temp_max': 32,
#   'pressure': 1025,
#   'humidity': 51},
#  'visibility': 10000,
#  'wind': {'speed': 5.75, 'deg': 310},
#  'clouds': {'all': 40},
#  'dt': 1610335832,
#  'sys': {'type': 1,
#   'id': 3486,
#   'country': 'US',
#   'sunrise': 1610280748,
#   'sunset': 1610314252},
#  'timezone': -18000,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Get the JSON data.
boston_data = city_weather.json()

# %%
boston_data['sys']["country"]
# Out:
# 'US'

# %%
boston_data["dt"]
# Out:
# 1610335832

# %%
lat = boston_data["coord"]["lat"]
lng = boston_data["coord"]["lon"]
max_temp = boston_data["main"]["temp_max"]
humidity = boston_data["main"]["humidity"]
clouds = boston_data["clouds"]["all"]
wind = boston_data["wind"]["speed"]
print(lat, lng, max_temp, humidity, clouds, wind)
# Out:
# 42.3584 -71.0598 32 51 40 5.75

# %%
# Import the datetime module from the datetime library.
from datetime import datetime
# Get the date from the JSON file.
date = boston_data["dt"]
# Convert the UTC date to a date format with year, month, day, hours, minutes, and seconds.
datetime.utcfromtimestamp(date)
# Out:
# datetime.datetime(2021, 1, 11, 3, 30, 32)

# %%
datetime.utcfromtimestamp(date).strftime('%Y-%m-%d %H:%M:%S')
# Out:
# '2021-01-11 03:30:32'

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")

record_count += 1

print("Done")
# Out:
# Processing Record 1 of Set 13 | rikitea
# Processing Record 2 of Set 13 | ushuaia
# Processing Record 3 of Set 13 | homer
# Processing Record 4 of Set 13 | batagay
# Processing Record 5 of Set 13 | arman
# Processing Record 6 of Set 13 | skjervoy
# Processing Record 7 of Set 13 | avarua
# Processing Record 8 of Set 13 | punta arenas
# Processing Record 9 of Set 13 | dikson
# Processing Record 10 of Set 13 | goundam
# Processing Record 11 of Set 13 | bengkulu
# Processing Record 12 of Set 13 | quatre cocos
# Processing Record 13 of Set 13 | caravelas
# Processing Record 14 of Set 13 | codrington
# Processing Record 15 of Set 13 | cape town
# Processing Record 16 of Set 13 | butaritari
# Processing Record 17 of Set 13 | taolanaro
# City not found. Skipping...
# Processing Record 18 of Set 13 | jamestown
# Processing Record 19 of Set 13 | te anau
# Processing Record 20 of Set 13 | lagoa
# Processing Record 21 of Set 13 | bolshaya irba
# City not found. Skipping...
# Processing Record 22 of Set 13 | mastung
# Processing Record 23 of Set 13 | bredasdorp
# Processing Record 24 of Set 13 | yarada
# Processing Record 25 of Set 13 | biak
# Processing Record 26 of Set 13 | saint-philippe
# Processing Record 27 of Set 13 | kavieng
# Processing Record 28 of Set 13 | parvatipuram
# Processing Record 29 of Set 13 | tecoanapa
# Processing Record 30 of Set 13 | khash
# Processing Record 31 of Set 13 | souillac
# Processing Record 32 of Set 13 | tuktoyaktuk
# Processing Record 33 of Set 13 | hilo
# Processing Record 34 of Set 13 | mys shmidta
# City not found. Skipping...
# Processing Record 35 of Set 13 | sirjan
# Processing Record 36 of Set 13 | arraial do cabo
# Processing Record 37 of Set 13 | sorland
# Processing Record 38 of Set 13 | upernavik
# Processing Record 39 of Set 13 | cidreira
# Processing Record 40 of Set 13 | alangayam
# Processing Record 41 of Set 13 | bluff
# Processing Record 42 of Set 13 | chicama
# Processing Record 43 of Set 13 | cabo rojo
# Processing Record 44 of Set 13 | cabo san lucas
# Processing Record 45 of Set 13 | atambua
# Processing Record 46 of Set 13 | soe
# Processing Record 47 of Set 13 | flinders
# Processing Record 48 of Set 13 | ponta do sol
# Processing Record 49 of Set 13 | doha
# Processing Record 50 of Set 13 | vaini
# Processing Record 1 of Set 14 | beringen
# Processing Record 2 of Set 14 | lashio
# Processing Record 3 of Set 14 | burica
# City not found. Skipping...
# Processing Record 4 of Set 14 | narsaq
# Processing Record 5 of Set 14 | kortkeros
# Processing Record 6 of Set 14 | lakselv
# Processing Record 7 of Set 14 | nemuro
# Processing Record 8 of Set 14 | poso
# Processing Record 9 of Set 14 | beloha
# Processing Record 10 of Set 14 | sentyabrskiy
# City not found. Skipping...
# Processing Record 11 of Set 14 | pangnirtung
# Processing Record 12 of Set 14 | haines junction
# Processing Record 13 of Set 14 | hamilton
# Processing Record 14 of Set 14 | tuatapere
# Processing Record 15 of Set 14 | torbay
# Processing Record 16 of Set 14 | kamenka
# Processing Record 17 of Set 14 | vilhena
# Processing Record 18 of Set 14 | laguna
# Processing Record 19 of Set 14 | kapaa
# Processing Record 20 of Set 14 | longyearbyen
# Processing Record 21 of Set 14 | tay ninh
# Processing Record 22 of Set 14 | spassk
# Processing Record 23 of Set 14 | ust-maya
# Processing Record 24 of Set 14 | araouane
# Processing Record 25 of Set 14 | saldanha
# Processing Record 26 of Set 14 | okandja
# City not found. Skipping...
# Processing Record 27 of Set 14 | yellowknife
# Processing Record 28 of Set 14 | port alfred
# Processing Record 29 of Set 14 | karasburg
# Processing Record 30 of Set 14 | puerto ayora
# Processing Record 31 of Set 14 | albany
# Processing Record 32 of Set 14 | todos santos
# Processing Record 33 of Set 14 | carnarvon
# Processing Record 34 of Set 14 | yumen
# Processing Record 35 of Set 14 | urusha
# Processing Record 36 of Set 14 | barrow
# Processing Record 37 of Set 14 | lompoc
# Processing Record 38 of Set 14 | geresk
# City not found. Skipping...
# Processing Record 39 of Set 14 | qaanaaq
# Processing Record 40 of Set 14 | sergeyevka
# Processing Record 41 of Set 14 | qui nhon
# Processing Record 42 of Set 14 | cookshire
# City not found. Skipping...
# Processing Record 43 of Set 14 | puerto cabezas
# Processing Record 44 of Set 14 | aitape
# Processing Record 45 of Set 14 | hobart
# Processing Record 46 of Set 14 | jaguariaiva
# Processing Record 47 of Set 14 | east london
# Processing Record 48 of Set 14 | salta
# Processing Record 49 of Set 14 | cherskiy
# Processing Record 50 of Set 14 | poum
# Processing Record 1 of Set 15 | castro
# Processing Record 2 of Set 15 | olafsvik
# Processing Record 3 of Set 15 | vaitupu
# City not found. Skipping...
# Processing Record 4 of Set 15 | chumikan
# Processing Record 5 of Set 15 | dunedin
# Processing Record 6 of Set 15 | saskylakh
# Processing Record 7 of Set 15 | lake wales
# Processing Record 8 of Set 15 | tirano
# Processing Record 9 of Set 15 | klaksvik
# Processing Record 10 of Set 15 | belushya guba
# City not found. Skipping...
# Processing Record 11 of Set 15 | miri
# Processing Record 12 of Set 15 | batagay-alyta
# Processing Record 13 of Set 15 | ribeira grande
# Processing Record 14 of Set 15 | mataura
# Processing Record 15 of Set 15 | muli
# Processing Record 16 of Set 15 | neiafu
# Processing Record 17 of Set 15 | thompson
# Processing Record 18 of Set 15 | tessalit
# Processing Record 19 of Set 15 | katsuura
# Processing Record 20 of Set 15 | faya
# Processing Record 21 of Set 15 | neuquen
# Processing Record 22 of Set 15 | beira
# Processing Record 23 of Set 15 | busselton
# Processing Record 24 of Set 15 | khatanga
# Processing Record 25 of Set 15 | atuona
# Processing Record 26 of Set 15 | tiksi
# Processing Record 27 of Set 15 | racconigi
# Processing Record 28 of Set 15 | huangzhai
# Processing Record 29 of Set 15 | nagua
# Processing Record 30 of Set 15 | pisco
# Processing Record 31 of Set 15 | chuy
# Processing Record 32 of Set 15 | kearney
# Processing Record 33 of Set 15 | susanino
# Processing Record 34 of Set 15 | semey
# Processing Record 35 of Set 15 | nguiu
# City not found. Skipping...
# Processing Record 36 of Set 15 | shaartuz
# City not found. Skipping...
# Processing Record 37 of Set 15 | hovd
# Processing Record 38 of Set 15 | margate
# Processing Record 39 of Set 15 | havre-saint-pierre
# Processing Record 40 of Set 15 | palmer
# Processing Record 41 of Set 15 | lebu
# Processing Record 42 of Set 15 | kangaatsiaq
# Processing Record 43 of Set 15 | port elizabeth
# Processing Record 44 of Set 15 | russell
# Processing Record 45 of Set 15 | kaoma
# Processing Record 46 of Set 15 | lata
# Processing Record 47 of Set 15 | kazerun
# Processing Record 48 of Set 15 | severo-kurilsk
# Processing Record 49 of Set 15 | bethel
# Processing Record 50 of Set 15 | kenitra
# Processing Record 1 of Set 16 | okato
# Processing Record 2 of Set 16 | marzuq
# Processing Record 3 of Set 16 | kashary
# Processing Record 4 of Set 16 | saint-pierre
# Processing Record 5 of Set 16 | ust-omchug
# Processing Record 6 of Set 16 | hithadhoo
# Processing Record 7 of Set 16 | woodward
# Processing Record 8 of Set 16 | kyzyl-suu
# Processing Record 9 of Set 16 | nome
# Processing Record 10 of Set 16 | lorengau
# Processing Record 11 of Set 16 | donskoye
# Processing Record 12 of Set 16 | daru
# Processing Record 13 of Set 16 | makokou
# Processing Record 14 of Set 16 | revelstoke
# Processing Record 15 of Set 16 | hermanus
# Processing Record 16 of Set 16 | gat
# Processing Record 17 of Set 16 | port blair
# Processing Record 18 of Set 16 | airai
# Processing Record 19 of Set 16 | coihaique
# Processing Record 20 of Set 16 | amderma
# City not found. Skipping...
# Processing Record 21 of Set 16 | dingle
# Processing Record 22 of Set 16 | yerbogachen
# Processing Record 23 of Set 16 | miguel hidalgo
# Processing Record 24 of Set 16 | palabuhanratu
# City not found. Skipping...
# Processing Record 25 of Set 16 | tasiilaq
# Processing Record 26 of Set 16 | novikovo
# Processing Record 27 of Set 16 | muisne
# Processing Record 28 of Set 16 | saint george
# Processing Record 29 of Set 16 | attawapiskat
# City not found. Skipping...
# Processing Record 30 of Set 16 | berdigestyakh
# Processing Record 31 of Set 16 | kununurra
# Processing Record 32 of Set 16 | praia da vitoria
# Processing Record 33 of Set 16 | tallahassee
# Processing Record 34 of Set 16 | bambous virieux
# Processing Record 35 of Set 16 | iqaluit
# Processing Record 36 of Set 16 | hualmay
# Processing Record 37 of Set 16 | mar del plata
# Processing Record 38 of Set 16 | krasnoselkup
# Processing Record 39 of Set 16 | storslett
# Processing Record 40 of Set 16 | porto novo
# Processing Record 41 of Set 16 | port shepstone
# Processing Record 42 of Set 16 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 43 of Set 16 | takaka
# Processing Record 44 of Set 16 | isangel
# Processing Record 45 of Set 16 | kushima
# Processing Record 46 of Set 16 | pyapon
# Processing Record 47 of Set 16 | aland
# Processing Record 48 of Set 16 | avera
# Processing Record 49 of Set 16 | barawe
# City not found. Skipping...
# Processing Record 50 of Set 16 | norman wells
# Processing Record 1 of Set 17 | burnham
# Processing Record 2 of Set 17 | caraquet
# Processing Record 3 of Set 17 | aksu
# Processing Record 4 of Set 17 | namibe
# Processing Record 5 of Set 17 | tena
# Processing Record 6 of Set 17 | krizevci
# Processing Record 7 of Set 17 | ahipara
# Processing Record 8 of Set 17 | barentsburg
# City not found. Skipping...
# Processing Record 9 of Set 17 | evensk
# Processing Record 10 of Set 17 | ilulissat
# Processing Record 11 of Set 17 | urumqi
# Processing Record 12 of Set 17 | artyk
# City not found. Skipping...
# Processing Record 13 of Set 17 | axim
# Processing Record 14 of Set 17 | ojinaga
# Processing Record 15 of Set 17 | nikolskoye
# Processing Record 16 of Set 17 | san patricio
# Processing Record 17 of Set 17 | qazvin
# Processing Record 18 of Set 17 | khandyga
# Processing Record 19 of Set 17 | baturaja
# Processing Record 20 of Set 17 | gravdal
# Processing Record 21 of Set 17 | harper
# Processing Record 22 of Set 17 | wahran
# City not found. Skipping...
# Processing Record 23 of Set 17 | tutoia
# Processing Record 24 of Set 17 | vila velha
# Processing Record 25 of Set 17 | wajir
# Processing Record 26 of Set 17 | grand-lahou
# Processing Record 27 of Set 17 | chokurdakh
# Processing Record 28 of Set 17 | shieli
# Processing Record 29 of Set 17 | asau
# Processing Record 30 of Set 17 | saint anthony
# Processing Record 31 of Set 17 | mahibadhoo
# Processing Record 32 of Set 17 | luderitz
# Processing Record 33 of Set 17 | bethanien
# Processing Record 34 of Set 17 | esperance
# Processing Record 35 of Set 17 | los llanos de aridane
# Processing Record 36 of Set 17 | nanortalik
# Processing Record 37 of Set 17 | hobyo
# Processing Record 38 of Set 17 | hami
# Processing Record 39 of Set 17 | san andres
# Processing Record 40 of Set 17 | guerrero negro
# Processing Record 41 of Set 17 | negele
# City not found. Skipping...
# Processing Record 42 of Set 17 | chengde
# Processing Record 43 of Set 17 | shirokiy
# Processing Record 44 of Set 17 | marawi
# Processing Record 45 of Set 17 | owando
# Processing Record 46 of Set 17 | coro
# Processing Record 47 of Set 17 | provideniya
# Processing Record 48 of Set 17 | ilebo
# Processing Record 49 of Set 17 | harnosand
# Processing Record 50 of Set 17 | bellavista
# Processing Record 1 of Set 18 | husavik
# Processing Record 2 of Set 18 | aklavik
# Processing Record 3 of Set 18 | chapais
# Processing Record 4 of Set 18 | sioux lookout
# Processing Record 5 of Set 18 | opunake
# Processing Record 6 of Set 18 | clyde river
# Processing Record 7 of Set 18 | siparia
# Processing Record 8 of Set 18 | victoria
# Processing Record 9 of Set 18 | bundaberg
# Processing Record 10 of Set 18 | nayoro
# Processing Record 11 of Set 18 | siniscola
# Processing Record 12 of Set 18 | tommot
# Processing Record 13 of Set 18 | portland
# Processing Record 14 of Set 18 | belaya gora
# Processing Record 15 of Set 18 | jadu
# Processing Record 16 of Set 18 | pathein
# Processing Record 17 of Set 18 | diffa
# Processing Record 18 of Set 18 | riyadh
# Processing Record 19 of Set 18 | san quintin
# Processing Record 20 of Set 18 | nouadhibou
# Processing Record 21 of Set 18 | sol-iletsk
# Processing Record 22 of Set 18 | le port
# Processing Record 23 of Set 18 | maridi
# Processing Record 24 of Set 18 | bargal
# City not found. Skipping...
# Processing Record 25 of Set 18 | fortuna
# Processing Record 26 of Set 18 | tilichiki
# Processing Record 27 of Set 18 | saint-joseph
# Processing Record 28 of Set 18 | itoman
# Processing Record 29 of Set 18 | kieta
# Processing Record 30 of Set 18 | rincon
# Processing Record 31 of Set 18 | fayaoue
# Processing Record 32 of Set 18 | san cristobal
# Processing Record 33 of Set 18 | manacapuru
# Processing Record 34 of Set 18 | saleaula
# City not found. Skipping...
# Processing Record 35 of Set 18 | lampang
# Processing Record 36 of Set 18 | new norfolk
# Processing Record 37 of Set 18 | georgetown
# Processing Record 38 of Set 18 | tanabe
# Processing Record 39 of Set 18 | kaitangata
# Processing Record 40 of Set 18 | malatya
# Processing Record 41 of Set 18 | nizhneyansk
# City not found. Skipping...
# Processing Record 42 of Set 18 | bathsheba
# Processing Record 43 of Set 18 | lavrentiya
# Processing Record 44 of Set 18 | marrakesh
# Processing Record 45 of Set 18 | sistranda
# Processing Record 46 of Set 18 | takoradi
# Processing Record 47 of Set 18 | trudarmeyskiy
# Processing Record 48 of Set 18 | salalah
# Processing Record 49 of Set 18 | puerto leguizamo
# Processing Record 50 of Set 18 | sargur
# Processing Record 1 of Set 19 | tygda
# Processing Record 2 of Set 19 | yulara
# Processing Record 3 of Set 19 | rio novo do sul
# Processing Record 4 of Set 19 | troy
# Processing Record 5 of Set 19 | makat
# Processing Record 6 of Set 19 | bouna
# Processing Record 7 of Set 19 | toppenish
# Processing Record 8 of Set 19 | fexhe-le-haut-clocher
# Processing Record 9 of Set 19 | darnah
# Processing Record 10 of Set 19 | eureka
# Processing Record 11 of Set 19 | sao gabriel da cachoeira
# Processing Record 12 of Set 19 | del rio
# Processing Record 13 of Set 19 | mitu
# Processing Record 14 of Set 19 | xining
# Processing Record 15 of Set 19 | zhangjiakou
# Processing Record 16 of Set 19 | stokmarknes
# Processing Record 17 of Set 19 | beringovskiy
# Processing Record 18 of Set 19 | bolungarvik
# City not found. Skipping...
# Processing Record 19 of Set 19 | piacabucu
# Processing Record 20 of Set 19 | varzea alegre
# Processing Record 21 of Set 19 | uroteppa
# City not found. Skipping...
# Processing Record 22 of Set 19 | grindavik
# Processing Record 23 of Set 19 | dhanera
# Processing Record 24 of Set 19 | canton
# Processing Record 25 of Set 19 | komsomolskiy
# Processing Record 26 of Set 19 | naze
# Processing Record 27 of Set 19 | meulaboh
# Processing Record 28 of Set 19 | camacha
# Processing Record 29 of Set 19 | samusu
# City not found. Skipping...
# Processing Record 30 of Set 19 | trinidad
# Processing Record 31 of Set 19 | abu dhabi
# Processing Record 32 of Set 19 | salamiyah
# Processing Record 33 of Set 19 | waw
# Processing Record 34 of Set 19 | america dourada
# Processing Record 35 of Set 19 | marcona
# City not found. Skipping...
# Processing Record 36 of Set 19 | fort saint john
# City not found. Skipping...
# Processing Record 37 of Set 19 | sampit
# Processing Record 38 of Set 19 | itarema
# Processing Record 39 of Set 19 | ostrovnoy
# Processing Record 40 of Set 19 | broome
# Processing Record 41 of Set 19 | hihifo
# City not found. Skipping...
# Processing Record 42 of Set 19 | teknaf
# Processing Record 43 of Set 19 | ahuimanu
# Processing Record 44 of Set 19 | nantucket
# Processing Record 45 of Set 19 | yinchuan
# Processing Record 46 of Set 19 | venice
# Processing Record 47 of Set 19 | seoul
# Processing Record 48 of Set 19 | humaita
# Processing Record 49 of Set 19 | sao filipe
# Processing Record 50 of Set 19 | kabin buri
# Processing Record 1 of Set 20 | aripuana
# Processing Record 2 of Set 20 | sur
# Processing Record 3 of Set 20 | wonthaggi
# Processing Record 4 of Set 20 | bubaque
# Processing Record 5 of Set 20 | tigil
# Processing Record 6 of Set 20 | greenville
# Processing Record 7 of Set 20 | menongue
# Processing Record 8 of Set 20 | emerald
# Processing Record 9 of Set 20 | zhangye
# Processing Record 10 of Set 20 | puerto colombia
# Processing Record 11 of Set 20 | bozeman
# Processing Record 12 of Set 20 | kavaratti
# Processing Record 13 of Set 20 | saint-lo
# Processing Record 14 of Set 20 | payakumbuh
# Processing Record 15 of Set 20 | langxiang
# Processing Record 16 of Set 20 | manyana
# Processing Record 17 of Set 20 | cehegin
# Processing Record 18 of Set 20 | nhulunbuy
# Processing Record 19 of Set 20 | bur gabo
# City not found. Skipping...
# Processing Record 20 of Set 20 | kloulklubed
# Processing Record 21 of Set 20 | shenjiamen
# Processing Record 22 of Set 20 | satitoa
# City not found. Skipping...
# Processing Record 23 of Set 20 | las cruces
# Processing Record 24 of Set 20 | ichinohe
# Processing Record 25 of Set 20 | milas
# Processing Record 26 of Set 20 | hervey bay
# Processing Record 27 of Set 20 | villarrica
# Processing Record 28 of Set 20 | mahebourg
# Processing Record 29 of Set 20 | makurdi
# Processing Record 30 of Set 20 | vila franca do campo
# Processing Record 31 of Set 20 | wichita falls
# Processing Record 32 of Set 20 | pevek
# Processing Record 33 of Set 20 | tokur
# Processing Record 34 of Set 20 | samarai
# Processing Record 35 of Set 20 | marion
# Processing Record 36 of Set 20 | lasa
# Processing Record 37 of Set 20 | acapulco
# Processing Record 38 of Set 20 | sandwich
# Processing Record 39 of Set 20 | pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 40 of Set 20 | padang
# Processing Record 41 of Set 20 | san jose
# Processing Record 42 of Set 20 | plattling
# Processing Record 43 of Set 20 | labytnangi
# Processing Record 44 of Set 20 | yaan
# Processing Record 45 of Set 20 | rawson
# Processing Record 46 of Set 20 | bilibino
# Processing Record 47 of Set 20 | chapayevka
# Processing Record 48 of Set 20 | sabya
# Processing Record 49 of Set 20 | charters towers
# Processing Record 50 of Set 20 | comodoro rivadavia
# Processing Record 1 of Set 21 | coahuayana
# Processing Record 2 of Set 21 | culfa
# Processing Record 3 of Set 21 | tomatlan
# Processing Record 4 of Set 21 | mavrovi anovi
# Processing Record 5 of Set 21 | george
# Processing Record 6 of Set 21 | kushiro
# Processing Record 7 of Set 21 | dvinskoy
# Processing Record 8 of Set 21 | cabedelo
# Processing Record 9 of Set 21 | port hardy
# Processing Record 10 of Set 21 | kalmunai
# Processing Record 11 of Set 21 | lamar
# Processing Record 12 of Set 21 | mbale
# Processing Record 13 of Set 21 | petauke
# Processing Record 14 of Set 21 | warqla
# City not found. Skipping...
# Processing Record 15 of Set 21 | trat
# Processing Record 16 of Set 21 | esso
# Processing Record 17 of Set 21 | mount gambier
# Processing Record 18 of Set 21 | yining
# Processing Record 19 of Set 21 | fukue
# Processing Record 20 of Set 21 | denpasar
# Processing Record 21 of Set 21 | ngukurr
# City not found. Skipping...
# Processing Record 22 of Set 21 | leningradskiy
# Processing Record 23 of Set 21 | muchkapskiy
# Processing Record 24 of Set 21 | grand river south east
# City not found. Skipping...
# Processing Record 25 of Set 21 | toora-khem
# Processing Record 26 of Set 21 | sabang
# Processing Record 27 of Set 21 | ryazanovskiy
# Processing Record 28 of Set 21 | praia
# Processing Record 29 of Set 21 | acarau
# Processing Record 30 of Set 21 | egvekinot
# Processing Record 31 of Set 21 | tsihombe
# City not found. Skipping...
# Processing Record 32 of Set 21 | joshimath
# Processing Record 33 of Set 21 | novyy urgal
# Processing Record 34 of Set 21 | goderich
# Processing Record 35 of Set 21 | stephenville
# Processing Record 36 of Set 21 | cockburn town
# Processing Record 37 of Set 21 | iskateley
# Processing Record 38 of Set 21 | jalu
# Processing Record 39 of Set 21 | bila tserkva
# Processing Record 40 of Set 21 | talaya
# Processing Record 41 of Set 21 | corinth
# Processing Record 42 of Set 21 | licata
# Processing Record 43 of Set 21 | half moon bay
# Processing Record 44 of Set 21 | yashkul
# Processing Record 45 of Set 21 | boralday
# Processing Record 46 of Set 21 | faanui
# Processing Record 47 of Set 21 | boa vista
# Processing Record 48 of Set 21 | pergamino
# Processing Record 49 of Set 21 | moron
# Processing Record 50 of Set 21 | ballina
# Processing Record 1 of Set 22 | waddan
# Processing Record 2 of Set 22 | hambantota
# Processing Record 3 of Set 22 | zhigansk
# Processing Record 4 of Set 22 | waverly
# Processing Record 5 of Set 22 | rundu
# Processing Record 6 of Set 22 | chihuahua
# Processing Record 7 of Set 22 | taltal
# Processing Record 8 of Set 22 | north platte
# Processing Record 9 of Set 22 | kodiak
# Processing Record 10 of Set 22 | heishan
# Processing Record 11 of Set 22 | floro
# Processing Record 12 of Set 22 | karaul
# City not found. Skipping...
# Processing Record 13 of Set 22 | klyuchi
# Processing Record 14 of Set 22 | pingzhuang
# Processing Record 15 of Set 22 | kathu
# Processing Record 16 of Set 22 | mahalingpur
# Processing Record 17 of Set 22 | touros
# Processing Record 18 of Set 22 | coquimbo
# Processing Record 19 of Set 22 | tura
# Processing Record 20 of Set 22 | neryungri
# Processing Record 21 of Set 22 | manta
# Processing Record 22 of Set 22 | beboto
# Processing Record 23 of Set 22 | lengshuitan
# Processing Record 24 of Set 22 | fonte boa
# Processing Record 25 of Set 22 | minab
# Processing Record 26 of Set 22 | mushie
# Processing Record 27 of Set 22 | ballinrobe
# Processing Record 28 of Set 22 | sidrolandia
# Processing Record 29 of Set 22 | talnakh
# Processing Record 30 of Set 22 | sarkand
# Processing Record 31 of Set 22 | chiang klang
# Processing Record 32 of Set 22 | ngunguru
# Processing Record 33 of Set 22 | bonthe
# Processing Record 34 of Set 22 | auxerre
# Processing Record 35 of Set 22 | puri
# Processing Record 36 of Set 22 | nuevo laredo
# Processing Record 37 of Set 22 | haibowan
# City not found. Skipping...
# Processing Record 38 of Set 22 | gorontalo
# Processing Record 39 of Set 22 | duverge
# Processing Record 40 of Set 22 | lima
# Processing Record 41 of Set 22 | coban
# Processing Record 42 of Set 22 | nioro
# Processing Record 43 of Set 22 | temaraia
# City not found. Skipping...
# Processing Record 44 of Set 22 | erdenet
# Processing Record 45 of Set 22 | casale monferrato
# Processing Record 46 of Set 22 | vardo
# Processing Record 47 of Set 22 | tias
# Processing Record 48 of Set 22 | vestmannaeyjar
# Processing Record 49 of Set 22 | port-cartier
# Processing Record 50 of Set 22 | igurubi
# Processing Record 1 of Set 23 | bowen
# Processing Record 2 of Set 23 | villa corzo
# Processing Record 3 of Set 23 | tonekabon
# Processing Record 4 of Set 23 | port lincoln
# Processing Record 5 of Set 23 | tombouctou
# Processing Record 6 of Set 23 | alice springs
# Processing Record 7 of Set 23 | ambon
# Processing Record 8 of Set 23 | saubara
# Processing Record 9 of Set 23 | mitsamiouli
# Processing Record 10 of Set 23 | saint-augustin
# Processing Record 11 of Set 23 | mahajanga
# Processing Record 12 of Set 23 | changli
# Processing Record 13 of Set 23 | the valley
# Processing Record 14 of Set 23 | ulaangom
# Processing Record 15 of Set 23 | karatau
# Processing Record 16 of Set 23 | cradock
# Processing Record 17 of Set 23 | nishihara
# Processing Record 18 of Set 23 | caraballeda
# Processing Record 19 of Set 23 | augusto correa
# Processing Record 20 of Set 23 | auki
# Processing Record 21 of Set 23 | karratha
# Processing Record 22 of Set 23 | plettenberg bay
# Processing Record 23 of Set 23 | iida
# Processing Record 24 of Set 23 | mezen
# Processing Record 25 of Set 23 | azuaga
# Processing Record 26 of Set 23 | toliary
# City not found. Skipping...
# Processing Record 27 of Set 23 | katesh
# Processing Record 28 of Set 23 | bridlington
# Processing Record 29 of Set 23 | jutai
# Processing Record 30 of Set 23 | berezovyy
# Processing Record 31 of Set 23 | guarapari
# Processing Record 32 of Set 23 | katangli
# Processing Record 33 of Set 23 | garden city
# Processing Record 34 of Set 23 | zhanatas
# City not found. Skipping...
# Processing Record 35 of Set 23 | mbandaka
# Processing Record 36 of Set 23 | revyakino
# Processing Record 37 of Set 23 | mtwara
# Processing Record 38 of Set 23 | rungata
# City not found. Skipping...
# Processing Record 39 of Set 23 | kawana waters
# City not found. Skipping...
# Processing Record 40 of Set 23 | sansepolcro
# Processing Record 41 of Set 23 | wilmington
# Processing Record 42 of Set 23 | kresttsy
# Processing Record 43 of Set 23 | a dos cunhados
# Processing Record 44 of Set 23 | vulcanesti
# Processing Record 45 of Set 23 | mahadday weyne
# City not found. Skipping...
# Processing Record 46 of Set 23 | cairns
# Processing Record 47 of Set 23 | mersin
# Processing Record 48 of Set 23 | praya
# Processing Record 49 of Set 23 | elliot lake
# Processing Record 50 of Set 23 | hohhot
# Processing Record 1 of Set 24 | lubbock
# Processing Record 2 of Set 24 | kingaroy
# Processing Record 3 of Set 24 | college
# Processing Record 4 of Set 24 | itoigawa
# Processing Record 5 of Set 24 | yongan
# Processing Record 6 of Set 24 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 7 of Set 24 | seydi
# Processing Record 8 of Set 24 | umm ruwabah
# City not found. Skipping...
# Processing Record 9 of Set 24 | fairbanks
# Processing Record 10 of Set 24 | gamba
# Processing Record 11 of Set 24 | natal
# Processing Record 12 of Set 24 | yenagoa
# Processing Record 13 of Set 24 | dalnegorsk
# Processing Record 14 of Set 24 | otane
# Processing Record 15 of Set 24 | blackwater
# Processing Record 16 of Set 24 | bouloupari
# Processing Record 17 of Set 24 | ghanzi
# Processing Record 18 of Set 24 | el bagre
# Processing Record 19 of Set 24 | smithers
# Processing Record 20 of Set 24 | mumford
# Processing Record 21 of Set 24 | kimberley
# Processing Record 22 of Set 24 | tarudant
# City not found. Skipping...
# Processing Record 23 of Set 24 | samarkand
# Processing Record 24 of Set 24 | kano
# Processing Record 25 of Set 24 | tobane
# Processing Record 26 of Set 24 | nizhniy odes
# Processing Record 27 of Set 24 | okhotsk
# Processing Record 28 of Set 24 | ishigaki
# Processing Record 29 of Set 24 | sangar
# Processing Record 30 of Set 24 | bahia de caraquez
# Processing Record 31 of Set 24 | taikang
# Processing Record 32 of Set 24 | port-gentil
# Processing Record 33 of Set 24 | havoysund
# Processing Record 34 of Set 24 | plomarion
# Processing Record 35 of Set 24 | oksfjord
# Processing Record 36 of Set 24 | korla
# Processing Record 37 of Set 24 | vangaindrano
# Processing Record 38 of Set 24 | trebisacce
# Processing Record 39 of Set 24 | tumannyy
# City not found. Skipping...
# Processing Record 40 of Set 24 | saint-junien
# Processing Record 41 of Set 24 | sao joao da barra
# Processing Record 42 of Set 24 | nizhniy baskunchak
# Processing Record 43 of Set 24 | maragogi
# Processing Record 44 of Set 24 | alegrete
# Processing Record 45 of Set 24 | sakakah
# Processing Record 46 of Set 24 | kahului
# Processing Record 47 of Set 24 | yatou
# Processing Record 48 of Set 24 | rawah
# Processing Record 49 of Set 24 | bardstown
# Processing Record 50 of Set 24 | bolshoye sorokino
# City not found. Skipping...
# Processing Record 1 of Set 25 | miquelon
# Processing Record 2 of Set 25 | abrau-dyurso
# Processing Record 3 of Set 25 | winsum
# Processing Record 4 of Set 25 | houma
# Processing Record 5 of Set 25 | mandalgovi
# Processing Record 6 of Set 25 | japura
# Done

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Rikitea -23.1203 -134.9692     78.28        79          42
# 1       Ushuaia -54.8000  -68.3000     42.80        70          75
# 2         Homer  59.6425 -151.5483     39.20        81          90
# 3       Batagay  67.6333  134.6333    -33.56        81          59
# 4         Arman  59.7000  150.1667     -4.99        81         100
# 5      Skjervoy  70.0311   20.9714     22.80        90          86
# 6        Avarua -21.2078 -159.7750     82.40        74          84
# 7  Punta Arenas -53.1500  -70.9167     42.80        70          40
# 8        Dikson  73.5069   80.5464     19.17        97         100
# 9       Goundam  16.4145   -3.6708     66.72        36           0
#
#    Wind Speed Country                 Date
# 0       17.83      PF  2021-01-11 03:34:29
# 1       21.85      AR  2021-01-11 03:30:43
# 2       12.66      US  2021-01-11 03:34:29
# 3        3.60      RU  2021-01-11 03:25:08
# 4       11.10      RU  2021-01-11 03:34:30
# 5       17.00      NO  2021-01-11 03:34:30
# 6       10.36      CK  2021-01-11 03:34:30
# 7        9.22      CL  2021-01-11 03:34:30
# 8       12.91      RU  2021-01-11 03:34:31
# 9       14.58      ML  2021-01-11 03:31:44

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import the time module.
import time
# Get today's date in seconds.
today = time.strftime("%x")
today
# Out:
# '01/10/21'

# %%
# Import time module
import time

# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()

# %%
# Import linear regression from the SciPy stats module.
from scipy.stats import linregress

# %%
# Create an equal number of latitudes and temperatures.
lats = [42.5, 43.9, 8.1, 36.8, 79.9, 69.1, 25.7, 15.3, 12.7, 64.5]
temps = [80.5, 75.3, 90.9, 90.0, 40.4, 62.3, 85.4, 79.6, 72.5, 72.0]

# %%
# Perform linear regression.
(slope, intercept, r_value, p_value, std_err) = linregress(lats, temps)
# Get the equation of the line.
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
print(f"The p-value is: {p_value:.3f}")
# Out:
# y = -0.45x + 92.94
# The p-value is: 0.011

# %%
# Calculate the regression line "y values" from the slope and intercept.
regress_values = [(lat * slope + intercept) for lat in lats]

# %%
# Import Matplotlib.
import matplotlib.pyplot as plt
# Create a scatter plot of the x and y values.
plt.scatter(lats,temps)
# Plot the regression line with the x-values and the y coordinates based on the intercept and slope.
plt.plot(lats,regress_values,"r")
# Annotate the text for the line equation and add its coordinates.
plt.annotate(line_eq, (10,40), fontsize=15, color="red")
plt.xlabel('Latitude')
plt.ylabel('Temp')
plt.show()

# %%
# Import linregress
from scipy.stats import linregress

# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):

    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
index13 = city_data_df.loc[13] 
index13
# Out:
# City                   Codrington
# Lat                      -38.2667
# Lng                       141.967
# Max Temp                    94.69
# Humidity                       19
# Cloudiness                    100
# Wind Speed                  19.98
# Country                        AU
# Date          2021-01-11 03:34:32
# Name: 13, dtype: object

# %%
city_data_df["Lat"] >= 0
# Out:
# 0      False
# 1      False
# 2       True
# 3       True
# 4       True
#        ...
# 551     True
# 552     True
# 553     True
# 554     True
# 555    False
# Name: Lat, Length: 556, dtype: bool

# %%
city_data_df.loc[(city_data_df["Lat"] >= 0)].head()
# Out:
#        City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 2     Homer  59.6425 -151.5483     39.20        81          90       12.66
# 3   Batagay  67.6333  134.6333    -33.56        81          59        3.60
# 4     Arman  59.7000  150.1667     -4.99        81         100       11.10
# 5  Skjervoy  70.0311   20.9714     22.80        90          86       17.00
# 8    Dikson  73.5069   80.5464     19.17        97         100       12.91
#
#   Country                 Date
# 2      US  2021-01-11 03:34:29
# 3      RU  2021-01-11 03:25:08
# 4      RU  2021-01-11 03:34:30
# 5      NO  2021-01-11 03:34:30
# 8      RU  2021-01-11 03:34:31

# %%
# Create Northern and Southern Hemisphere DataFrames.
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(10,40))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(-50,90))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for % Humidity', '% Humidity',(40,10))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                       for % Humidity', '% Humidity',(-50,15))

# %%
# SKILL DRILL Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
# Call the function
plot_linear_regression(x_values, y_values,
                   'Linear Regression on the Northern Hemisphere \
                    for % Cloudiness', '% Cloudiness',(10,55))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for % Cloudiness', '% Cloudiness',(-50,60))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Wind Speed', 'Wind Speed',(40,35))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for Wind Speed', 'Wind Speed',(-50,35))

# %%
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-68-546b7ee8bd33> in <module>
#       4 import requests
#       5 # Import the API key.
# ----> 6 from config import g_key
#
# ImportError: cannot import name 'g_key' from 'config' (C:\Users\Dr. Awesome\Desktop\Weather\World_Weather_Analysis\config.py)

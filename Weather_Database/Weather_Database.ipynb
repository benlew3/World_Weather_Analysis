# %%
#Import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

#Use the citipy module to determine city based on latitude and longitude
from citipy import citipy

# %%
#Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90.000, 90.000, size = 2000)
lngs = np.random.uniform(-180.000, 180.000, size = 2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
#Create a list for holding the cities
cities = []

#Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    #If the city is unique, then we will add it to the cities list
    if city not in cities:
        cities.append(city)
        
#Print the city count to confirm sufficient count
len(cities)
# Out:
# 765

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

#Import the datetime module from the datetime library
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#Create an empty list to hold the weather data
city_data = []

#Print the beginning of the logging
print("Beginning Data Retrieval     ")
print("-----------------------------")

#Create counters
record_count = 1
set_count = 1

#loop through all the cities in the list
for i, city in enumerate(cities):
    
    #Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >=50):
        set_count += 1
        record_count = 1
    
    #Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    #Lot the URL, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    #Add 1 to the record count
    record_count += 1
    
    #Run an API request for each of the cities
    try:
        #Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        
        #Parse out the needed data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        #Append the city information into city_data list
        city_data.append({"City": city.title(),
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_humidity,
                         "Cloudiness": city_clouds,
                         "Wind Speed": city_wind,
                         "Country": city_country,
                         "Current Description": city_description})
    
    #If an error is experienced, skip the city
    except:
        print("City not found.  Skipping...")
        pass
    
#Indicate that Data Loading is complete
print("-----------------------")
print("Data Retrieval Complete")
print("-----------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kaitangata
# Processing Record 2 of Set 1 | amderma
# City not found.  Skipping...
# Processing Record 3 of Set 1 | tasiilaq
# Processing Record 4 of Set 1 | geraldton
# Processing Record 5 of Set 1 | pisco
# Processing Record 6 of Set 1 | kavaratti
# Processing Record 7 of Set 1 | port alfred
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | cape town
# Processing Record 10 of Set 1 | rungata
# City not found.  Skipping...
# Processing Record 11 of Set 1 | saint-georges
# Processing Record 12 of Set 1 | kapit
# Processing Record 13 of Set 1 | anchorage
# Processing Record 14 of Set 1 | port-gentil
# Processing Record 15 of Set 1 | tomatlan
# Processing Record 16 of Set 1 | carnarvon
# Processing Record 17 of Set 1 | vaini
# Processing Record 18 of Set 1 | georgetown
# Processing Record 19 of Set 1 | rikitea
# Processing Record 20 of Set 1 | kharan
# Processing Record 21 of Set 1 | longyearbyen
# Processing Record 22 of Set 1 | svetlogorsk
# Processing Record 23 of Set 1 | barentsburg
# City not found.  Skipping...
# Processing Record 24 of Set 1 | saskylakh
# Processing Record 25 of Set 1 | puerto ayora
# Processing Record 26 of Set 1 | raton
# Processing Record 27 of Set 1 | busselton
# Processing Record 28 of Set 1 | buraydah
# Processing Record 29 of Set 1 | balkanabat
# Processing Record 30 of Set 1 | saint-philippe
# Processing Record 31 of Set 1 | goderich
# Processing Record 32 of Set 1 | port elizabeth
# Processing Record 33 of Set 1 | savinka
# Processing Record 34 of Set 1 | bluff
# Processing Record 35 of Set 1 | hatton
# Processing Record 36 of Set 1 | karaul
# City not found.  Skipping...
# Processing Record 37 of Set 1 | hobart
# Processing Record 38 of Set 1 | arraial do cabo
# Processing Record 39 of Set 1 | avarua
# Processing Record 40 of Set 1 | kupang
# Processing Record 41 of Set 1 | agnibilekrou
# Processing Record 42 of Set 1 | cidreira
# Processing Record 43 of Set 1 | illoqqortoormiut
# City not found.  Skipping...
# Processing Record 44 of Set 1 | sobolevo
# Processing Record 45 of Set 1 | vaitupu
# City not found.  Skipping...
# Processing Record 46 of Set 1 | ahipara
# Processing Record 47 of Set 1 | marquette
# Processing Record 48 of Set 1 | singapore
# Processing Record 49 of Set 1 | sao miguel do araguaia
# Processing Record 50 of Set 1 | hermanus
# Processing Record 1 of Set 2 | kalabo
# Processing Record 2 of Set 2 | jieshi
# Processing Record 3 of Set 2 | butaritari
# Processing Record 4 of Set 2 | santa rosa
# Processing Record 5 of Set 2 | ribeira grande
# Processing Record 6 of Set 2 | yellowknife
# Processing Record 7 of Set 2 | curaca
# Processing Record 8 of Set 2 | derzhavinsk
# Processing Record 9 of Set 2 | beloha
# Processing Record 10 of Set 2 | necochea
# Processing Record 11 of Set 2 | newport
# Processing Record 12 of Set 2 | samalaeulu
# City not found.  Skipping...
# Processing Record 13 of Set 2 | north bend
# Processing Record 14 of Set 2 | umbuzeiro
# Processing Record 15 of Set 2 | soma
# Processing Record 16 of Set 2 | kapaa
# Processing Record 17 of Set 2 | grand river south east
# City not found.  Skipping...
# Processing Record 18 of Set 2 | panguna
# Processing Record 19 of Set 2 | atuona
# Processing Record 20 of Set 2 | cuenca
# Processing Record 21 of Set 2 | chernyshevskiy
# Processing Record 22 of Set 2 | tubruq
# City not found.  Skipping...
# Processing Record 23 of Set 2 | waingapu
# Processing Record 24 of Set 2 | tuktoyaktuk
# Processing Record 25 of Set 2 | mataura
# Processing Record 26 of Set 2 | kuche
# City not found.  Skipping...
# Processing Record 27 of Set 2 | kahului
# Processing Record 28 of Set 2 | lata
# Processing Record 29 of Set 2 | kualakapuas
# Processing Record 30 of Set 2 | faanui
# Processing Record 31 of Set 2 | airai
# Processing Record 32 of Set 2 | urucui
# Processing Record 33 of Set 2 | san patricio
# Processing Record 34 of Set 2 | punta arenas
# Processing Record 35 of Set 2 | sovetskiy
# Processing Record 36 of Set 2 | lubango
# Processing Record 37 of Set 2 | victoria
# Processing Record 38 of Set 2 | kurilsk
# Processing Record 39 of Set 2 | ayios matthaios
# City not found.  Skipping...
# Processing Record 40 of Set 2 | sentyabrskiy
# City not found.  Skipping...
# Processing Record 41 of Set 2 | ibra
# Processing Record 42 of Set 2 | ancud
# Processing Record 43 of Set 2 | mar del plata
# Processing Record 44 of Set 2 | provideniya
# Processing Record 45 of Set 2 | hasaki
# Processing Record 46 of Set 2 | springbok
# Processing Record 47 of Set 2 | tiksi
# Processing Record 48 of Set 2 | nikolskoye
# Processing Record 49 of Set 2 | lebu
# Processing Record 50 of Set 2 | yelovo
# Processing Record 1 of Set 3 | henties bay
# Processing Record 2 of Set 3 | cayenne
# Processing Record 3 of Set 3 | pervomayskoye
# Processing Record 4 of Set 3 | dudinka
# Processing Record 5 of Set 3 | dauriya
# Processing Record 6 of Set 3 | nong chik
# Processing Record 7 of Set 3 | talas
# Processing Record 8 of Set 3 | nakusp
# Processing Record 9 of Set 3 | kuybyshevo
# Processing Record 10 of Set 3 | albany
# Processing Record 11 of Set 3 | torbay
# Processing Record 12 of Set 3 | bengkulu
# Processing Record 13 of Set 3 | mahebourg
# Processing Record 14 of Set 3 | husavik
# Processing Record 15 of Set 3 | xiaoweizhai
# Processing Record 16 of Set 3 | mabaruma
# Processing Record 17 of Set 3 | zhangjiakou
# Processing Record 18 of Set 3 | ardakan
# Processing Record 19 of Set 3 | codrington
# Processing Record 20 of Set 3 | olafsvik
# Processing Record 21 of Set 3 | jamestown
# Processing Record 22 of Set 3 | ushtobe
# Processing Record 23 of Set 3 | woodstock
# Processing Record 24 of Set 3 | sur
# Processing Record 25 of Set 3 | khash
# Processing Record 26 of Set 3 | kibre mengist
# Processing Record 27 of Set 3 | turukhansk
# Processing Record 28 of Set 3 | severnoye
# Processing Record 29 of Set 3 | buin
# Processing Record 30 of Set 3 | kavieng
# Processing Record 31 of Set 3 | tuapse
# Processing Record 32 of Set 3 | nieuw amsterdam
# Processing Record 33 of Set 3 | khatanga
# Processing Record 34 of Set 3 | yatou
# Processing Record 35 of Set 3 | jiddah
# City not found.  Skipping...
# Processing Record 36 of Set 3 | ola
# Processing Record 37 of Set 3 | redwater
# Processing Record 38 of Set 3 | gobabis
# Processing Record 39 of Set 3 | vilcun
# Processing Record 40 of Set 3 | taolanaro
# City not found.  Skipping...
# Processing Record 41 of Set 3 | talnakh
# Processing Record 42 of Set 3 | acajutla
# Processing Record 43 of Set 3 | yar-sale
# Processing Record 44 of Set 3 | spring valley
# Processing Record 45 of Set 3 | bria
# Processing Record 46 of Set 3 | kadykchan
# City not found.  Skipping...
# Processing Record 47 of Set 3 | itoman
# Processing Record 48 of Set 3 | riyadh
# Processing Record 49 of Set 3 | olmos
# Processing Record 50 of Set 3 | elizabeth city
# Processing Record 1 of Set 4 | sitka
# Processing Record 2 of Set 4 | tumannyy
# City not found.  Skipping...
# Processing Record 3 of Set 4 | antanifotsy
# Processing Record 4 of Set 4 | luderitz
# Processing Record 5 of Set 4 | ndiekro
# City not found.  Skipping...
# Processing Record 6 of Set 4 | mys shmidta
# City not found.  Skipping...
# Processing Record 7 of Set 4 | salinopolis
# Processing Record 8 of Set 4 | severo-kurilsk
# Processing Record 9 of Set 4 | bikin
# Processing Record 10 of Set 4 | ilulissat
# Processing Record 11 of Set 4 | dikson
# Processing Record 12 of Set 4 | jalu
# Processing Record 13 of Set 4 | cassia
# Processing Record 14 of Set 4 | kamaishi
# Processing Record 15 of Set 4 | haines junction
# Processing Record 16 of Set 4 | maizuru
# Processing Record 17 of Set 4 | iglino
# Processing Record 18 of Set 4 | andenes
# Processing Record 19 of Set 4 | madimba
# Processing Record 20 of Set 4 | sinjai
# Processing Record 21 of Set 4 | manggar
# Processing Record 22 of Set 4 | ponta delgada
# Processing Record 23 of Set 4 | grindavik
# Processing Record 24 of Set 4 | qaanaaq
# Processing Record 25 of Set 4 | barrow
# Processing Record 26 of Set 4 | pacific grove
# Processing Record 27 of Set 4 | nurota
# Processing Record 28 of Set 4 | poum
# Processing Record 29 of Set 4 | muleba
# Processing Record 30 of Set 4 | esperance
# Processing Record 31 of Set 4 | stepnogorsk
# Processing Record 32 of Set 4 | chaozhou
# Processing Record 33 of Set 4 | bay city
# Processing Record 34 of Set 4 | fevralsk
# City not found.  Skipping...
# Processing Record 35 of Set 4 | new norfolk
# Processing Record 36 of Set 4 | kattivakkam
# Processing Record 37 of Set 4 | susanville
# Processing Record 38 of Set 4 | berlevag
# Processing Record 39 of Set 4 | arman
# Processing Record 40 of Set 4 | anito
# Processing Record 41 of Set 4 | iqaluit
# Processing Record 42 of Set 4 | hutchinson
# Processing Record 43 of Set 4 | mataya
# Processing Record 44 of Set 4 | longlac
# City not found.  Skipping...
# Processing Record 45 of Set 4 | saint-joseph
# Processing Record 46 of Set 4 | altay
# Processing Record 47 of Set 4 | campoverde
# Processing Record 48 of Set 4 | avera
# Processing Record 49 of Set 4 | dundalk
# Processing Record 50 of Set 4 | westport
# Processing Record 1 of Set 5 | pevek
# Processing Record 2 of Set 5 | lufilufi
# Processing Record 3 of Set 5 | tuatapere
# Processing Record 4 of Set 5 | bethel
# Processing Record 5 of Set 5 | kargopol
# Processing Record 6 of Set 5 | kruisfontein
# Processing Record 7 of Set 5 | guerrero negro
# Processing Record 8 of Set 5 | vao
# Processing Record 9 of Set 5 | vila velha
# Processing Record 10 of Set 5 | taltal
# Processing Record 11 of Set 5 | louisbourg
# City not found.  Skipping...
# Processing Record 12 of Set 5 | hamilton
# Processing Record 13 of Set 5 | nyurba
# Processing Record 14 of Set 5 | fukue
# Processing Record 15 of Set 5 | portland
# Processing Record 16 of Set 5 | constitucion
# Processing Record 17 of Set 5 | atherton
# Processing Record 18 of Set 5 | cabo san lucas
# Processing Record 19 of Set 5 | vostok
# Processing Record 20 of Set 5 | krapivinskiy
# Processing Record 21 of Set 5 | atar
# Processing Record 22 of Set 5 | comodoro rivadavia
# Processing Record 23 of Set 5 | belomorsk
# Processing Record 24 of Set 5 | la ronge
# Processing Record 25 of Set 5 | aklavik
# Processing Record 26 of Set 5 | hithadhoo
# Processing Record 27 of Set 5 | kodiak
# Processing Record 28 of Set 5 | markova
# Processing Record 29 of Set 5 | hami
# Processing Record 30 of Set 5 | praia
# Processing Record 31 of Set 5 | half moon bay
# Processing Record 32 of Set 5 | honiara
# Processing Record 33 of Set 5 | nantucket
# Processing Record 34 of Set 5 | castro
# Processing Record 35 of Set 5 | saint-pierre
# Processing Record 36 of Set 5 | thompson
# Processing Record 37 of Set 5 | tecpan
# Processing Record 38 of Set 5 | bollnas
# Processing Record 39 of Set 5 | nome
# Processing Record 40 of Set 5 | waipawa
# Processing Record 41 of Set 5 | padang
# Processing Record 42 of Set 5 | talakan
# Processing Record 43 of Set 5 | togur
# Processing Record 44 of Set 5 | erenhot
# Processing Record 45 of Set 5 | ust-kut
# Processing Record 46 of Set 5 | tunghsiao
# City not found.  Skipping...
# Processing Record 47 of Set 5 | kirakira
# Processing Record 48 of Set 5 | ballina
# Processing Record 49 of Set 5 | iracoubo
# Processing Record 50 of Set 5 | galgani
# City not found.  Skipping...
# Processing Record 1 of Set 6 | plavsk
# Processing Record 2 of Set 6 | camacha
# Processing Record 3 of Set 6 | namibe
# Processing Record 4 of Set 6 | nanortalik
# Processing Record 5 of Set 6 | flinders
# Processing Record 6 of Set 6 | yulara
# Processing Record 7 of Set 6 | sherlovaya gora
# Processing Record 8 of Set 6 | ambon
# Processing Record 9 of Set 6 | vila franca do campo
# Processing Record 10 of Set 6 | sambava
# Processing Record 11 of Set 6 | vilyuysk
# Processing Record 12 of Set 6 | alofi
# Processing Record 13 of Set 6 | oranjemund
# Processing Record 14 of Set 6 | victor harbor
# Processing Record 15 of Set 6 | jaisalmer
# Processing Record 16 of Set 6 | hay river
# Processing Record 17 of Set 6 | klaksvik
# Processing Record 18 of Set 6 | sao miguel
# Processing Record 19 of Set 6 | los llanos de aridane
# Processing Record 20 of Set 6 | gamba
# Processing Record 21 of Set 6 | muros
# Processing Record 22 of Set 6 | gorodishche
# Processing Record 23 of Set 6 | hilo
# Processing Record 24 of Set 6 | okhotsk
# Processing Record 25 of Set 6 | bemidji
# Processing Record 26 of Set 6 | seymchan
# Processing Record 27 of Set 6 | lashio
# Processing Record 28 of Set 6 | melendugno
# Processing Record 29 of Set 6 | qiongshan
# Processing Record 30 of Set 6 | canchungo
# Processing Record 31 of Set 6 | chokurdakh
# Processing Record 32 of Set 6 | balfour
# Processing Record 33 of Set 6 | sira
# Processing Record 34 of Set 6 | viedma
# Processing Record 35 of Set 6 | nanzhang
# Processing Record 36 of Set 6 | vitim
# Processing Record 37 of Set 6 | tessalit
# Processing Record 38 of Set 6 | begowal
# Processing Record 39 of Set 6 | huron
# Processing Record 40 of Set 6 | vigo
# Processing Record 41 of Set 6 | marcona
# City not found.  Skipping...
# Processing Record 42 of Set 6 | shingu
# Processing Record 43 of Set 6 | dunedin
# Processing Record 44 of Set 6 | yirol
# City not found.  Skipping...
# Processing Record 45 of Set 6 | katsuura
# Processing Record 46 of Set 6 | hobyo
# Processing Record 47 of Set 6 | san cristobal
# Processing Record 48 of Set 6 | vuktyl
# Processing Record 49 of Set 6 | den helder
# Processing Record 50 of Set 6 | makakilo city
# Processing Record 1 of Set 7 | east london
# Processing Record 2 of Set 7 | karakendzha
# City not found.  Skipping...
# Processing Record 3 of Set 7 | tsihombe
# City not found.  Skipping...
# Processing Record 4 of Set 7 | lavrentiya
# Processing Record 5 of Set 7 | ixtapa
# Processing Record 6 of Set 7 | shelopugino
# Processing Record 7 of Set 7 | vianopolis
# Processing Record 8 of Set 7 | leningradskiy
# Processing Record 9 of Set 7 | kailua
# Processing Record 10 of Set 7 | barbar
# City not found.  Skipping...
# Processing Record 11 of Set 7 | longonjo
# Processing Record 12 of Set 7 | camopi
# Processing Record 13 of Set 7 | jacqueville
# Processing Record 14 of Set 7 | belushya guba
# City not found.  Skipping...
# Processing Record 15 of Set 7 | envira
# Processing Record 16 of Set 7 | nicoya
# Processing Record 17 of Set 7 | namangan
# Processing Record 18 of Set 7 | vigia
# Processing Record 19 of Set 7 | yacuiba
# Processing Record 20 of Set 7 | lock haven
# Processing Record 21 of Set 7 | poplar bluff
# Processing Record 22 of Set 7 | bredasdorp
# Processing Record 23 of Set 7 | zeya
# Processing Record 24 of Set 7 | upata
# Processing Record 25 of Set 7 | palana
# Processing Record 26 of Set 7 | artyk
# City not found.  Skipping...
# Processing Record 27 of Set 7 | sorvag
# City not found.  Skipping...
# Processing Record 28 of Set 7 | nanzhou
# Processing Record 29 of Set 7 | mokhotlong
# Processing Record 30 of Set 7 | rio gallegos
# Processing Record 31 of Set 7 | bogorodskoye
# Processing Record 32 of Set 7 | narsaq
# Processing Record 33 of Set 7 | saleaula
# City not found.  Skipping...
# Processing Record 34 of Set 7 | moses lake
# Processing Record 35 of Set 7 | villa bisono
# Processing Record 36 of Set 7 | rudnogorsk
# Processing Record 37 of Set 7 | cumaribo
# City not found.  Skipping...
# Processing Record 38 of Set 7 | haibowan
# City not found.  Skipping...
# Processing Record 39 of Set 7 | paamiut
# Processing Record 40 of Set 7 | anloga
# Processing Record 41 of Set 7 | svetlaya
# Processing Record 42 of Set 7 | progreso
# Processing Record 43 of Set 7 | simao
# Processing Record 44 of Set 7 | samusu
# City not found.  Skipping...
# Processing Record 45 of Set 7 | cherskiy
# Processing Record 46 of Set 7 | upernavik
# Processing Record 47 of Set 7 | palabuhanratu
# City not found.  Skipping...
# Processing Record 48 of Set 7 | ararat
# Processing Record 49 of Set 7 | san quintin
# Processing Record 50 of Set 7 | san vicente
# Processing Record 1 of Set 8 | aksu
# Processing Record 2 of Set 8 | komsomolskiy
# Processing Record 3 of Set 8 | coquimbo
# Processing Record 4 of Set 8 | seoul
# Processing Record 5 of Set 8 | the valley
# Processing Record 6 of Set 8 | namatanai
# Processing Record 7 of Set 8 | nizhneyansk
# City not found.  Skipping...
# Processing Record 8 of Set 8 | guanare
# Processing Record 9 of Set 8 | ponta do sol
# Processing Record 10 of Set 8 | methoni
# Processing Record 11 of Set 8 | bima
# Processing Record 12 of Set 8 | inyonga
# Processing Record 13 of Set 8 | walvis bay
# Processing Record 14 of Set 8 | trairi
# Processing Record 15 of Set 8 | carutapera
# Processing Record 16 of Set 8 | beipiao
# Processing Record 17 of Set 8 | bazarnyy karabulak
# Processing Record 18 of Set 8 | fort nelson
# Processing Record 19 of Set 8 | fier
# Processing Record 20 of Set 8 | buala
# Processing Record 21 of Set 8 | umm lajj
# Processing Record 22 of Set 8 | inhambane
# Processing Record 23 of Set 8 | tateyama
# Processing Record 24 of Set 8 | bontang
# Processing Record 25 of Set 8 | alpinopolis
# Processing Record 26 of Set 8 | nelson bay
# Processing Record 27 of Set 8 | saint anthony
# Processing Record 28 of Set 8 | puri
# Processing Record 29 of Set 8 | karamea
# City not found.  Skipping...
# Processing Record 30 of Set 8 | great yarmouth
# Processing Record 31 of Set 8 | mwinilunga
# Processing Record 32 of Set 8 | lagoa
# Processing Record 33 of Set 8 | chuy
# Processing Record 34 of Set 8 | bambous virieux
# Processing Record 35 of Set 8 | gornopravdinsk
# Processing Record 36 of Set 8 | agadez
# Processing Record 37 of Set 8 | chapada dos guimaraes
# Processing Record 38 of Set 8 | lorengau
# Processing Record 39 of Set 8 | ouadda
# Processing Record 40 of Set 8 | chapayevka
# Processing Record 41 of Set 8 | cururupu
# Processing Record 42 of Set 8 | pinyug
# Processing Record 43 of Set 8 | ilebo
# Processing Record 44 of Set 8 | isangel
# Processing Record 45 of Set 8 | anaconda
# Processing Record 46 of Set 8 | palmer
# Processing Record 47 of Set 8 | noormarkku
# Processing Record 48 of Set 8 | evensk
# Processing Record 49 of Set 8 | dabeiba
# Processing Record 50 of Set 8 | tura
# Processing Record 1 of Set 9 | katghora
# Processing Record 2 of Set 9 | mityana
# Processing Record 3 of Set 9 | puyang
# Processing Record 4 of Set 9 | lipin bor
# Processing Record 5 of Set 9 | bitung
# Processing Record 6 of Set 9 | puerto quijarro
# Processing Record 7 of Set 9 | nuuk
# Processing Record 8 of Set 9 | arica
# Processing Record 9 of Set 9 | tallahassee
# Processing Record 10 of Set 9 | northam
# Processing Record 11 of Set 9 | rabo de peixe
# Processing Record 12 of Set 9 | kamenka
# Processing Record 13 of Set 9 | de aar
# Processing Record 14 of Set 9 | visakhapatnam
# Processing Record 15 of Set 9 | loukhi
# Processing Record 16 of Set 9 | christchurch
# Processing Record 17 of Set 9 | eyl
# Processing Record 18 of Set 9 | vaitape
# Processing Record 19 of Set 9 | luanda
# Processing Record 20 of Set 9 | isla vista
# Processing Record 21 of Set 9 | fairbanks
# Processing Record 22 of Set 9 | magdagachi
# Processing Record 23 of Set 9 | alice springs
# Processing Record 24 of Set 9 | kandrian
# Processing Record 25 of Set 9 | meyungs
# City not found.  Skipping...
# Processing Record 26 of Set 9 | chingirlau
# Processing Record 27 of Set 9 | nsanje
# Processing Record 28 of Set 9 | amga
# Processing Record 29 of Set 9 | saldanha
# Processing Record 30 of Set 9 | shido
# Processing Record 31 of Set 9 | vitry-le-francois
# Processing Record 32 of Set 9 | hihifo
# City not found.  Skipping...
# Processing Record 33 of Set 9 | betafo
# Processing Record 34 of Set 9 | schwedt
# Processing Record 35 of Set 9 | surab
# Processing Record 36 of Set 9 | aksarka
# Processing Record 37 of Set 9 | clonakilty
# Processing Record 38 of Set 9 | blagoyevo
# Processing Record 39 of Set 9 | andevoranto
# City not found.  Skipping...
# Processing Record 40 of Set 9 | sabha
# Processing Record 41 of Set 9 | omboue
# Processing Record 42 of Set 9 | mahendranagar
# Processing Record 43 of Set 9 | mount gambier
# Processing Record 44 of Set 9 | road town
# Processing Record 45 of Set 9 | urumqi
# Processing Record 46 of Set 9 | halalo
# City not found.  Skipping...
# Processing Record 47 of Set 9 | ijui
# Processing Record 48 of Set 9 | general pico
# Processing Record 49 of Set 9 | fortuna
# Processing Record 50 of Set 9 | moerai
# Processing Record 1 of Set 10 | grand gaube
# Processing Record 2 of Set 10 | gerash
# Processing Record 3 of Set 10 | hashimoto
# Processing Record 4 of Set 10 | kapuskasing
# Processing Record 5 of Set 10 | mackay
# Processing Record 6 of Set 10 | pangody
# Processing Record 7 of Set 10 | saint-augustin
# Processing Record 8 of Set 10 | erzin
# Processing Record 9 of Set 10 | springdale
# Processing Record 10 of Set 10 | ushirombo
# Processing Record 11 of Set 10 | bilma
# Processing Record 12 of Set 10 | shahrud
# Processing Record 13 of Set 10 | yeppoon
# Processing Record 14 of Set 10 | diego de almagro
# Processing Record 15 of Set 10 | zavyalovo
# Processing Record 16 of Set 10 | wembley
# Processing Record 17 of Set 10 | attawapiskat
# City not found.  Skipping...
# Processing Record 18 of Set 10 | havre-saint-pierre
# Processing Record 19 of Set 10 | port hedland
# Processing Record 20 of Set 10 | honningsvag
# Processing Record 21 of Set 10 | teahupoo
# Processing Record 22 of Set 10 | marshalltown
# Processing Record 23 of Set 10 | tautira
# Processing Record 24 of Set 10 | khani
# Processing Record 25 of Set 10 | otradnoye
# Processing Record 26 of Set 10 | sisimiut
# Processing Record 27 of Set 10 | kamenskoye
# City not found.  Skipping...
# Processing Record 28 of Set 10 | taitung
# Processing Record 29 of Set 10 | senneterre
# Processing Record 30 of Set 10 | pucara
# Processing Record 31 of Set 10 | hambantota
# Processing Record 32 of Set 10 | samarai
# Processing Record 33 of Set 10 | toamasina
# Processing Record 34 of Set 10 | bahia honda
# Processing Record 35 of Set 10 | saposoa
# Processing Record 36 of Set 10 | naze
# Processing Record 37 of Set 10 | vitimskiy
# City not found.  Skipping...
# Processing Record 38 of Set 10 | noumea
# Processing Record 39 of Set 10 | katherine
# Processing Record 40 of Set 10 | almaznyy
# Processing Record 41 of Set 10 | norman wells
# Processing Record 42 of Set 10 | toliary
# City not found.  Skipping...
# Processing Record 43 of Set 10 | iztapa
# Processing Record 44 of Set 10 | jatai
# Processing Record 45 of Set 10 | morondava
# Processing Record 46 of Set 10 | te anau
# Processing Record 47 of Set 10 | majene
# Processing Record 48 of Set 10 | dneprovskaya
# Processing Record 49 of Set 10 | ozernovskiy
# Processing Record 50 of Set 10 | groningen
# Processing Record 1 of Set 11 | le port
# Processing Record 2 of Set 11 | uitenhage
# Processing Record 3 of Set 11 | yingkou
# Processing Record 4 of Set 11 | goundam
# Processing Record 5 of Set 11 | zyryanka
# Processing Record 6 of Set 11 | zhaotong
# Processing Record 7 of Set 11 | tarakan
# Processing Record 8 of Set 11 | puerto suarez
# Processing Record 9 of Set 11 | itupiranga
# Processing Record 10 of Set 11 | soledade
# Processing Record 11 of Set 11 | kiama
# Processing Record 12 of Set 11 | korem
# Processing Record 13 of Set 11 | port hardy
# Processing Record 14 of Set 11 | divnogorsk
# Processing Record 15 of Set 11 | kantunilkin
# Processing Record 16 of Set 11 | salalah
# Processing Record 17 of Set 11 | zhangye
# Processing Record 18 of Set 11 | ljubinje
# Processing Record 19 of Set 11 | sioux lookout
# Processing Record 20 of Set 11 | marsh harbour
# Processing Record 21 of Set 11 | mullaitivu
# City not found.  Skipping...
# Processing Record 22 of Set 11 | birao
# Processing Record 23 of Set 11 | kloulklubed
# Processing Record 24 of Set 11 | san pedro
# Processing Record 25 of Set 11 | shakiso
# Processing Record 26 of Set 11 | crowley
# Processing Record 27 of Set 11 | tashtyp
# Processing Record 28 of Set 11 | tazovskiy
# Processing Record 29 of Set 11 | san fernando
# Processing Record 30 of Set 11 | krasnoselkup
# Processing Record 31 of Set 11 | clyde river
# Processing Record 32 of Set 11 | savalou
# Processing Record 33 of Set 11 | venustiano carranza
# Processing Record 34 of Set 11 | clinton
# Processing Record 35 of Set 11 | gikongoro
# Processing Record 36 of Set 11 | mehamn
# Processing Record 37 of Set 11 | plettenberg bay
# Processing Record 38 of Set 11 | balimo
# City not found.  Skipping...
# Processing Record 39 of Set 11 | bubaque
# Processing Record 40 of Set 11 | mandera
# Processing Record 41 of Set 11 | sungairaya
# Processing Record 42 of Set 11 | souillac
# Processing Record 43 of Set 11 | shagonar

# %%
#Convert the array of dictionaries to a Pandas dataframe
city_data_df = pd.DataFrame(city_data)

#Reorder the dataframe columns
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)

# %%
#Create the output file (CSV)
output_data_file = "../Weather_Database/WeatherPy_Database.csv"

#Export the city data into a csv
city_data_df.to_csv(output_data_file, index_label = "City_ID")
